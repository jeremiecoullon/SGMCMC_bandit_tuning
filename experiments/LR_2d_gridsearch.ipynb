# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import time
import os
from pathlib import Path

import jax.numpy as jnp
from jax import random, jit, grad, vmap, partial

import context
from examples.logistic_regression.logistic_regression_model import gen_data_and_log_post
from samplers.sgld import sgld_jaxloop, sgld_kernel, sgld_time_budget
from samplers.sgldcv import sgld_kernel_CV, sgld_time_budget_CV
from ksd import imq_KSD

# %% [markdown]
# ## LR grid search
#
# Grid search for logistic regression. Uses a time budget
#
# - See bottom of notebook for reproducing the figures

# %%
dim = 10
Ndata = 100000
key = random.PRNGKey(0) # same key as 'LR-evaluate_default_vs_KSD.ipynb'
theta_true, X, y_data, val_and_grad_log_post = gen_data_and_log_post(key, dim, Ndata)

# testing and training data
num_train = int(Ndata*0.8)

X_train = X[:num_train]
X_test = X[num_train:]

y_train = y_data[:num_train]
y_test = y_data[num_train:]
del X, y_data


def LR_grad(theta):
    _, mygrad = val_and_grad_log_post(theta, X_train, y_train)
    return mygrad

batch_LR_grad = jit(vmap(LR_grad))


def get_ksd_LR_2_KSD(key, log_dt, log_batch_size_ratio, time_budget, CV):
    dt = 10**log_dt
    batch_size_ratio = 10**(log_batch_size_ratio)
    batch_size = int(X_train.shape[0]*batch_size_ratio)
    if CV == False:
        sgld_samples, sgld_grads = sgld_time_budget(key, val_and_grad_log_post, X_train,
                                                    y_train, time_budget, dt,
                                                    batch_size=batch_size, x_0=theta_true)
    else:
        sgld_samples, sgld_grads = sgld_time_budget_CV(key, val_and_grad_log_post, X_train,
                                                       y_train, time_budget, dt,
                                                       batch_size=batch_size, mean_param=theta_true, x_0=theta_true)
    if time_budget == 1:
        thin_step = 1
    elif time_budget == 5:
        thin_step = 5
    else:
        raise ValueError("time budget should be 1 or 5.")
    est_KSD_true_gradients = imq_KSD(sgld_samples[::thin_step], batch_LR_grad(sgld_samples[::thin_step]))
    return est_KSD_true_gradients


def grid_search_2D_LR(time_budget, logdt_grid, log_b_s_r_grid, CV):
    key = random.PRNGKey(100)
    XX, YY = np.meshgrid(logdt_grid, log_b_s_r_grid)
    ksd_mat_LR = np.zeros((len(log_b_s_r_grid), len(logdt_grid)))

    for i in range(len(log_b_s_r_grid)):
        for j in range(len(logdt_grid)):
            print(f"trying out {i,j}..")
            ksd_mat_LR[i,j] = get_ksd_LR_2_KSD(key, logdt_grid[j], log_b_s_r_grid[i], time_budget, CV)
            print(f"KSD for (logdt, log_b_s_r)={logdt_grid[j], log_b_s_r_grid[i]}: {ksd_mat_LR[i,j]:.2f}")

    return ksd_mat_LR
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# generating data, with N=100000 and dim=10

# %% [markdown]
# ### make directories

# %%
output_dir = f"outputs/LR_grid_search/sgld_CV_5sec"
Path(output_dir).mkdir(exist_ok=True)

output_dir = f"outputs/LR_grid_search/sgld_5sec"
Path(output_dir).mkdir(exist_ok=True)

# %%
# ====
# low-resolution grids:
# ---------------------
# logdt_grid = np.arange(-7,-2.6, 0.2)
# log_b_s_r_grid = np.arange(-5., 0., 0.4) # sgld-CV
# log_b_s_r_grid = np.arange(-3.5, 0., 0.4) # sgld
# ====
time_budget = 5.

for CV_bool in [True, False]:
    if CV_bool:
        logdt_grid = np.linspace(-5.2,-3, 22)
        log_b_s_r_grid = np.linspace(-4, 0.5, 17)
        output_dir = "outputs/LR_grid_search/sgld_CV_5sec"
    else:
        logdt_grid = np.linspace(-5.3,-3.6, 22)
        log_b_s_r_grid = np.linspace(-2.2,0, 17)
        
        output_dir = "outputs/LR_grid_search/sgld_5sec"
    
    CV_string = "_CV" if CV_bool else ""
    print(f"\nRunning sgld{CV_string} for a time budget of 5 sec..")
    ksd_mat_LR = grid_search_2D_LR(time_budget, logdt_grid, log_b_s_r_grid, CV_bool)
    np.savetxt(f"{output_dir}/LR_2D_gridsearch_high_res_sgld{CV_string}_5sec.txt", ksd_mat_LR)
    print("Done.")

print("Done.")
# Out:
# Running sgld_CV for a time budget of 5 sec..
# trying out (0, 0)..
# KSD for (logdt, log_b_s_r)=(-5.2, -4.0): 16.81
# trying out (0, 1)..
# KSD for (logdt, log_b_s_r)=(-5.095238095238096, -4.0): 15.00
# trying out (0, 2)..
# KSD for (logdt, log_b_s_r)=(-4.9904761904761905, -4.0): 13.53
# trying out (0, 3)..
# KSD for (logdt, log_b_s_r)=(-4.885714285714286, -4.0): 12.72
# trying out (0, 4)..
# KSD for (logdt, log_b_s_r)=(-4.780952380952381, -4.0): 11.76
# trying out (0, 5)..
# KSD for (logdt, log_b_s_r)=(-4.6761904761904765, -4.0): 11.36
# trying out (0, 6)..
# KSD for (logdt, log_b_s_r)=(-4.571428571428571, -4.0): 11.24
# trying out (0, 7)..
# KSD for (logdt, log_b_s_r)=(-4.466666666666667, -4.0): 10.76
# trying out (0, 8)..
# KSD for (logdt, log_b_s_r)=(-4.361904761904762, -4.0): 11.45
# trying out (0, 9)..
# KSD for (logdt, log_b_s_r)=(-4.257142857142857, -4.0): 12.66
# trying out (0, 10)..
# KSD for (logdt, log_b_s_r)=(-4.152380952380953, -4.0): 16.61
# trying out (0, 11)..
# KSD for (logdt, log_b_s_r)=(-4.0476190476190474, -4.0): 27.52
# trying out (0, 12)..
# KSD for (logdt, log_b_s_r)=(-3.942857142857143, -4.0): 66.01
# trying out (0, 13)..
# KSD for (logdt, log_b_s_r)=(-3.8380952380952382, -4.0): 246.04
# trying out (0, 14)..
# KSD for (logdt, log_b_s_r)=(-3.7333333333333334, -4.0): 629.36
# trying out (0, 15)..
# KSD for (logdt, log_b_s_r)=(-3.628571428571429, -4.0): 759.90
# trying out (0, 16)..
# KSD for (logdt, log_b_s_r)=(-3.5238095238095237, -4.0): 748.70
# trying out (0, 17)..
# KSD for (logdt, log_b_s_r)=(-3.4190476190476193, -4.0): 666.50
# trying out (0, 18)..
# KSD for (logdt, log_b_s_r)=(-3.3142857142857145, -4.0): 622.96
# trying out (0, 19)..
# KSD for (logdt, log_b_s_r)=(-3.2095238095238097, -4.0): 555.89
# trying out (0, 20)..
# KSD for (logdt, log_b_s_r)=(-3.104761904761905, -4.0): 500.28
# trying out (0, 21)..
# KSD for (logdt, log_b_s_r)=(-3.0, -4.0): 447.93
# trying out (1, 0)..
# KSD for (logdt, log_b_s_r)=(-5.2, -3.71875): 19.73
# trying out (1, 1)..
# KSD for (logdt, log_b_s_r)=(-5.095238095238096, -3.71875): 17.75
# trying out (1, 2)..
# KSD for (logdt, log_b_s_r)=(-4.9904761904761905, -3.71875): 16.71
# trying out (1, 3)..
# KSD for (logdt, log_b_s_r)=(-4.885714285714286, -3.71875): 14.68
# trying out (1, 4)..
# KSD for (logdt, log_b_s_r)=(-4.780952380952381, -3.71875): 11.55
# trying out (1, 5)..
# KSD for (logdt, log_b_s_r)=(-4.6761904761904765, -3.71875): 12.57
# trying out (1, 6)..
# KSD for (logdt, log_b_s_r)=(-4.571428571428571, -3.71875): 10.59
# trying out (1, 7)..
# KSD for (logdt, log_b_s_r)=(-4.466666666666667, -3.71875): 9.49
# trying out (1, 8)..
# KSD for (logdt, log_b_s_r)=(-4.361904761904762, -3.71875): 9.38
# trying out (1, 9)..
# KSD for (logdt, log_b_s_r)=(-4.257142857142857, -3.71875): 9.27
# trying out (1, 10)..
# KSD for (logdt, log_b_s_r)=(-4.152380952380953, -3.71875): 9.71
# trying out (1, 11)..
# KSD for (logdt, log_b_s_r)=(-4.0476190476190474, -3.71875): 11.86
# trying out (1, 12)..
# KSD for (logdt, log_b_s_r)=(-3.942857142857143, -3.71875): 16.37
# trying out (1, 13)..
# KSD for (logdt, log_b_s_r)=(-3.8380952380952382, -3.71875): 27.33
# trying out (1, 14)..
# KSD for (logdt, log_b_s_r)=(-3.7333333333333334, -3.71875): 72.26
# trying out (1, 15)..
# KSD for (logdt, log_b_s_r)=(-3.628571428571429, -3.71875): 300.33
# trying out (1, 16)..
# KSD for (logdt, log_b_s_r)=(-3.5238095238095237, -3.71875): 654.24
# trying out (1, 17)..
# KSD for (logdt, log_b_s_r)=(-3.4190476190476193, -3.71875): 758.09
# trying out (1, 18)..
# KSD for (logdt, log_b_s_r)=(-3.3142857142857145, -3.71875): 730.22
# trying out (1, 19)..
# KSD for (logdt, log_b_s_r)=(-3.2095238095238097, -3.71875): 696.07
# trying out (1, 20)..
# KSD for (logdt, log_b_s_r)=(-3.104761904761905, -3.71875): 627.80
# trying out (1, 21)..
# KSD for (logdt, log_b_s_r)=(-3.0, -3.71875): 567.56
# trying out (2, 0)..
# KSD for (logdt, log_b_s_r)=(-5.2, -3.4375): 17.61
# trying out (2, 1)..
# KSD for (logdt, log_b_s_r)=(-5.095238095238096, -3.4375): 16.06
# trying out (2, 2)..
# KSD for (logdt, log_b_s_r)=(-4.9904761904761905, -3.4375): 14.66
# trying out (2, 3)..
# KSD for (logdt, log_b_s_r)=(-4.885714285714286, -3.4375): 13.39
# trying out (2, 4)..
# KSD for (logdt, log_b_s_r)=(-4.780952380952381, -3.4375): 11.98
# trying out (2, 5)..
# KSD for (logdt, log_b_s_r)=(-4.6761904761904765, -3.4375): 10.92
# trying out (2, 6)..
# KSD for (logdt, log_b_s_r)=(-4.571428571428571, -3.4375): 10.25
# trying out (2, 7)..
# KSD for (logdt, log_b_s_r)=(-4.466666666666667, -3.4375): 9.47
# trying out (2, 8)..
# KSD for (logdt, log_b_s_r)=(-4.361904761904762, -3.4375): 8.79
# trying out (2, 9)..
# KSD for (logdt, log_b_s_r)=(-4.257142857142857, -3.4375): 8.43
# trying out (2, 10)..
# KSD for (logdt, log_b_s_r)=(-4.152380952380953, -3.4375): 8.45
# trying out (2, 11)..
# KSD for (logdt, log_b_s_r)=(-4.0476190476190474, -3.4375): 8.85
# trying out (2, 12)..
# KSD for (logdt, log_b_s_r)=(-3.942857142857143, -3.4375): 9.89
# trying out (2, 13)..
# KSD for (logdt, log_b_s_r)=(-3.8380952380952382, -3.4375): 12.47
# trying out (2, 14)..
# KSD for (logdt, log_b_s_r)=(-3.7333333333333334, -3.4375): 18.30
# trying out (2, 15)..
# KSD for (logdt, log_b_s_r)=(-3.628571428571429, -3.4375): 36.37
# trying out (2, 16)..
# KSD for (logdt, log_b_s_r)=(-3.5238095238095237, -3.4375): 144.58
# trying out (2, 17)..
# KSD for (logdt, log_b_s_r)=(-3.4190476190476193, -3.4375): 531.36
# trying out (2, 18)..
# KSD for (logdt, log_b_s_r)=(-3.3142857142857145, -3.4375): 746.77
# trying out (2, 19)..
# KSD for (logdt, log_b_s_r)=(-3.2095238095238097, -3.4375): 793.85
# trying out (2, 20)..
# KSD for (logdt, log_b_s_r)=(-3.104761904761905, -3.4375): 771.21
# trying out (2, 21)..
# KSD for (logdt, log_b_s_r)=(-3.0, -3.4375): 688.08
# trying out (3, 0)..
# KSD for (logdt, log_b_s_r)=(-5.2, -3.15625): 15.82
# trying out (3, 1)..
# KSD for (logdt, log_b_s_r)=(-5.095238095238096, -3.15625): 15.13
# trying out (3, 2)..
# KSD for (logdt, log_b_s_r)=(-4.9904761904761905, -3.15625): 13.58
# trying out (3, 3)..
# KSD for (logdt, log_b_s_r)=(-4.885714285714286, -3.15625): 11.39
# trying out (3, 4)..
# KSD for (logdt, log_b_s_r)=(-4.780952380952381, -3.15625): 10.84
# trying out (3, 5)..
# KSD for (logdt, log_b_s_r)=(-4.6761904761904765, -3.15625): 9.73
# trying out (3, 6)..
# KSD for (logdt, log_b_s_r)=(-4.571428571428571, -3.15625): 8.65
# trying out (3, 7)..
# KSD for (logdt, log_b_s_r)=(-4.466666666666667, -3.15625): 7.85
# trying out (3, 8)..
# KSD for (logdt, log_b_s_r)=(-4.361904761904762, -3.15625): 6.64
# trying out (3, 9)..
# KSD for (logdt, log_b_s_r)=(-4.257142857142857, -3.15625): 6.56
# trying out (3, 10)..
# KSD for (logdt, log_b_s_r)=(-4.152380952380953, -3.15625): 5.72
# trying out (3, 11)..
# KSD for (logdt, log_b_s_r)=(-4.0476190476190474, -3.15625): 5.32
# trying out (3, 12)..
# KSD for (logdt, log_b_s_r)=(-3.942857142857143, -3.15625): 5.56
# trying out (3, 13)..
# KSD for (logdt, log_b_s_r)=(-3.8380952380952382, -3.15625): 6.24
# trying out (3, 14)..
# KSD for (logdt, log_b_s_r)=(-3.7333333333333334, -3.15625): 8.14
# trying out (3, 15)..
# KSD for (logdt, log_b_s_r)=(-3.628571428571429, -3.15625): 12.61
# trying out (3, 16)..
# KSD for (logdt, log_b_s_r)=(-3.5238095238095237, -3.15625): 29.47
# trying out (3, 17)..
# KSD for (logdt, log_b_s_r)=(-3.4190476190476193, -3.15625): 186.43
# trying out (3, 18)..
# KSD for (logdt, log_b_s_r)=(-3.3142857142857145, -3.15625): 616.23
# trying out (3, 19)..
# KSD for (logdt, log_b_s_r)=(-3.2095238095238097, -3.15625): 835.45
# trying out (3, 20)..
# KSD for (logdt, log_b_s_r)=(-3.104761904761905, -3.15625): 863.04
# trying out (3, 21)..
# KSD for (logdt, log_b_s_r)=(-3.0, -3.15625): 831.02
# trying out (4, 0)..
# KSD for (logdt, log_b_s_r)=(-5.2, -2.875): 16.30
# trying out (4, 1)..
# KSD for (logdt, log_b_s_r)=(-5.095238095238096, -2.875): 15.44
# trying out (4, 2)..
# KSD for (logdt, log_b_s_r)=(-4.9904761904761905, -2.875): 13.00
# trying out (4, 3)..
# KSD for (logdt, log_b_s_r)=(-4.885714285714286, -2.875): 12.23
# trying out (4, 4)..
# KSD for (logdt, log_b_s_r)=(-4.780952380952381, -2.875): 11.08
# trying out (4, 5)..
# KSD for (logdt, log_b_s_r)=(-4.6761904761904765, -2.875): 9.97
# trying out (4, 6)..
# KSD for (logdt, log_b_s_r)=(-4.571428571428571, -2.875): 9.08
# trying out (4, 7)..
# KSD for (logdt, log_b_s_r)=(-4.466666666666667, -2.875): 8.08
# trying out (4, 8)..
# KSD for (logdt, log_b_s_r)=(-4.361904761904762, -2.875): 7.84
# trying out (4, 9)..
# KSD for (logdt, log_b_s_r)=(-4.257142857142857, -2.875): 7.30
# trying out (4, 10)..
# KSD for (logdt, log_b_s_r)=(-4.152380952380953, -2.875): 7.08
# trying out (4, 11)..
# KSD for (logdt, log_b_s_r)=(-4.0476190476190474, -2.875): 6.75
# trying out (4, 12)..
# KSD for (logdt, log_b_s_r)=(-3.942857142857143, -2.875): 7.13
# trying out (4, 13)..
# KSD for (logdt, log_b_s_r)=(-3.8380952380952382, -2.875): 7.44
# trying out (4, 14)..
# KSD for (logdt, log_b_s_r)=(-3.7333333333333334, -2.875): 8.64
# trying out (4, 15)..
# KSD for (logdt, log_b_s_r)=(-3.628571428571429, -2.875): 10.51
# trying out (4, 16)..
# KSD for (logdt, log_b_s_r)=(-3.5238095238095237, -2.875): 15.73
# trying out (4, 17)..
# KSD for (logdt, log_b_s_r)=(-3.4190476190476193, -2.875): 68.05
# trying out (4, 18)..
# KSD for (logdt, log_b_s_r)=(-3.3142857142857145, -2.875): 598.43
# trying out (4, 19)..
# KSD for (logdt, log_b_s_r)=(-3.2095238095238097, -2.875): 935.12
# trying out (4, 20)..
# KSD for (logdt, log_b_s_r)=(-3.104761904761905, -2.875): 1007.12
# trying out (4, 21)..
# KSD for (logdt, log_b_s_r)=(-3.0, -2.875): 993.48
# trying out (5, 0)..
# KSD for (logdt, log_b_s_r)=(-5.2, -2.59375): 16.53
# trying out (5, 1)..
# KSD for (logdt, log_b_s_r)=(-5.095238095238096, -2.59375): 14.72
# trying out (5, 2)..
# KSD for (logdt, log_b_s_r)=(-4.9904761904761905, -2.59375): 12.39
# trying out (5, 3)..
# KSD for (logdt, log_b_s_r)=(-4.885714285714286, -2.59375): 11.34
# trying out (5, 4)..
# KSD for (logdt, log_b_s_r)=(-4.780952380952381, -2.59375): 9.92
# trying out (5, 5)..
# KSD for (logdt, log_b_s_r)=(-4.6761904761904765, -2.59375): 9.02
# trying out (5, 6)..
# KSD for (logdt, log_b_s_r)=(-4.571428571428571, -2.59375): 7.83
# trying out (5, 7)..
# KSD for (logdt, log_b_s_r)=(-4.466666666666667, -2.59375): 6.97
# trying out (5, 8)..
# KSD for (logdt, log_b_s_r)=(-4.361904761904762, -2.59375): 6.25
# trying out (5, 9)..
# KSD for (logdt, log_b_s_r)=(-4.257142857142857, -2.59375): 5.87
# trying out (5, 10)..
# KSD for (logdt, log_b_s_r)=(-4.152380952380953, -2.59375): 5.61
# trying out (5, 11)..
# KSD for (logdt, log_b_s_r)=(-4.0476190476190474, -2.59375): 4.93
# trying out (5, 12)..
# KSD for (logdt, log_b_s_r)=(-3.942857142857143, -2.59375): 4.64
# trying out (5, 13)..
# KSD for (logdt, log_b_s_r)=(-3.8380952380952382, -2.59375): 4.58
# trying out (5, 14)..
# KSD for (logdt, log_b_s_r)=(-3.7333333333333334, -2.59375): 4.90
# trying out (5, 15)..
# KSD for (logdt, log_b_s_r)=(-3.628571428571429, -2.59375): 5.28
# trying out (5, 16)..
# KSD for (logdt, log_b_s_r)=(-3.5238095238095237, -2.59375): 7.56
# trying out (5, 17)..
# KSD for (logdt, log_b_s_r)=(-3.4190476190476193, -2.59375): 28.27
# trying out (5, 18)..
# KSD for (logdt, log_b_s_r)=(-3.3142857142857145, -2.59375): 715.94
# trying out (5, 19)..
# KSD for (logdt, log_b_s_r)=(-3.2095238095238097, -2.59375): 1201.49
# trying out (5, 20)..
# KSD for (logdt, log_b_s_r)=(-3.104761904761905, -2.59375): 1298.44
# trying out (5, 21)..
# KSD for (logdt, log_b_s_r)=(-3.0, -2.59375): 1293.45
# trying out (6, 0)..
# KSD for (logdt, log_b_s_r)=(-5.2, -2.3125): 15.76
# trying out (6, 1)..
# KSD for (logdt, log_b_s_r)=(-5.095238095238096, -2.3125): 14.16
# trying out (6, 2)..
# KSD for (logdt, log_b_s_r)=(-4.9904761904761905, -2.3125): 13.41
# trying out (6, 3)..
# KSD for (logdt, log_b_s_r)=(-4.885714285714286, -2.3125): 11.58
# trying out (6, 4)..
# KSD for (logdt, log_b_s_r)=(-4.780952380952381, -2.3125): 10.08
# trying out (6, 5)..
# KSD for (logdt, log_b_s_r)=(-4.6761904761904765, -2.3125): 8.97
# trying out (6, 6)..
# KSD for (logdt, log_b_s_r)=(-4.571428571428571, -2.3125): 8.55
# trying out (6, 7)..
# KSD for (logdt, log_b_s_r)=(-4.466666666666667, -2.3125): 7.29
# trying out (6, 8)..
# KSD for (logdt, log_b_s_r)=(-4.361904761904762, -2.3125): 6.90
# trying out (6, 9)..
# KSD for (logdt, log_b_s_r)=(-4.257142857142857, -2.3125): 6.33
# trying out (6, 10)..
# KSD for (logdt, log_b_s_r)=(-4.152380952380953, -2.3125): 5.63
# trying out (6, 11)..
# KSD for (logdt, log_b_s_r)=(-4.0476190476190474, -2.3125): 5.34
# trying out (6, 12)..
# KSD for (logdt, log_b_s_r)=(-3.942857142857143, -2.3125): 5.14
# trying out (6, 13)..
# KSD for (logdt, log_b_s_r)=(-3.8380952380952382, -2.3125): 5.56
# trying out (6, 14)..
# KSD for (logdt, log_b_s_r)=(-3.7333333333333334, -2.3125): 5.62
# trying out (6, 15)..
# KSD for (logdt, log_b_s_r)=(-3.628571428571429, -2.3125): 6.75
# trying out (6, 16)..
# KSD for (logdt, log_b_s_r)=(-3.5238095238095237, -2.3125): 7.98
# trying out (6, 17)..
# KSD for (logdt, log_b_s_r)=(-3.4190476190476193, -2.3125): 18.53
# trying out (6, 18)..
# KSD for (logdt, log_b_s_r)=(-3.3142857142857145, -2.3125): 1006.24
# trying out (6, 19)..
# KSD for (logdt, log_b_s_r)=(-3.2095238095238097, -2.3125): 1596.55
# trying out (6, 20)..
# KSD for (logdt, log_b_s_r)=(-3.104761904761905, -2.3125): 1757.48
# trying out (6, 21)..
# KSD for (logdt, log_b_s_r)=(-3.0, -2.3125): 1699.14
# trying out (7, 0)..
# KSD for (logdt, log_b_s_r)=(-5.2, -2.03125): 15.66
# trying out (7, 1)..
# KSD for (logdt, log_b_s_r)=(-5.095238095238096, -2.03125): 13.82
# trying out (7, 2)..
# KSD for (logdt, log_b_s_r)=(-4.9904761904761905, -2.03125): 12.57
# trying out (7, 3)..
# KSD for (logdt, log_b_s_r)=(-4.885714285714286, -2.03125): 11.40
# trying out (7, 4)..
# KSD for (logdt, log_b_s_r)=(-4.780952380952381, -2.03125): 9.90
# trying out (7, 5)..
# KSD for (logdt, log_b_s_r)=(-4.6761904761904765, -2.03125): 8.62
# trying out (7, 6)..
# KSD for (logdt, log_b_s_r)=(-4.571428571428571, -2.03125): 8.02
# trying out (7, 7)..
# KSD for (logdt, log_b_s_r)=(-4.466666666666667, -2.03125): 7.30
# trying out (7, 8)..
# KSD for (logdt, log_b_s_r)=(-4.361904761904762, -2.03125): 6.22
# trying out (7, 9)..
# KSD for (logdt, log_b_s_r)=(-4.257142857142857, -2.03125): 6.03
# trying out (7, 10)..
# KSD for (logdt, log_b_s_r)=(-4.152380952380953, -2.03125): 5.30
# trying out (7, 11)..
# KSD for (logdt, log_b_s_r)=(-4.0476190476190474, -2.03125): 5.02
# trying out (7, 12)..
# KSD for (logdt, log_b_s_r)=(-3.942857142857143, -2.03125): 5.23
# trying out (7, 13)..
# KSD for (logdt, log_b_s_r)=(-3.8380952380952382, -2.03125): 5.30
# trying out (7, 14)..
# KSD for (logdt, log_b_s_r)=(-3.7333333333333334, -2.03125): 5.12
# trying out (7, 15)..
# KSD for (logdt, log_b_s_r)=(-3.628571428571429, -2.03125): 6.03
# trying out (7, 16)..
# KSD for (logdt, log_b_s_r)=(-3.5238095238095237, -2.03125): 7.39
# trying out (7, 17)..
# KSD for (logdt, log_b_s_r)=(-3.4190476190476193, -2.03125): 14.73
# trying out (7, 18)..
# KSD for (logdt, log_b_s_r)=(-3.3142857142857145, -2.03125): 1260.00
# trying out (7, 19)..
# KSD for (logdt, log_b_s_r)=(-3.2095238095238097, -2.03125): 2125.30
# trying out (7, 20)..
# KSD for (logdt, log_b_s_r)=(-3.104761904761905, -2.03125): 2267.82
# trying out (7, 21)..
# KSD for (logdt, log_b_s_r)=(-3.0, -2.03125): 2249.27
# trying out (8, 0)..
# KSD for (logdt, log_b_s_r)=(-5.2, -1.75): 16.29
# trying out (8, 1)..
# KSD for (logdt, log_b_s_r)=(-5.095238095238096, -1.75): 15.12
# trying out (8, 2)..
# KSD for (logdt, log_b_s_r)=(-4.9904761904761905, -1.75): 13.55
# trying out (8, 3)..
# KSD for (logdt, log_b_s_r)=(-4.885714285714286, -1.75): 11.94
# trying out (8, 4)..
# KSD for (logdt, log_b_s_r)=(-4.780952380952381, -1.75): 10.78
# trying out (8, 5)..
# KSD for (logdt, log_b_s_r)=(-4.6761904761904765, -1.75): 9.64
# trying out (8, 6)..
# KSD for (logdt, log_b_s_r)=(-4.571428571428571, -1.75): 8.68
# trying out (8, 7)..
# KSD for (logdt, log_b_s_r)=(-4.466666666666667, -1.75): 7.74
# trying out (8, 8)..
# KSD for (logdt, log_b_s_r)=(-4.361904761904762, -1.75): 6.99
# trying out (8, 9)..
# KSD for (logdt, log_b_s_r)=(-4.257142857142857, -1.75): 6.40
# trying out (8, 10)..
# KSD for (logdt, log_b_s_r)=(-4.152380952380953, -1.75): 5.98
# trying out (8, 11)..
# KSD for (logdt, log_b_s_r)=(-4.0476190476190474, -1.75): 5.73
# trying out (8, 12)..
# KSD for (logdt, log_b_s_r)=(-3.942857142857143, -1.75): 5.56
# trying out (8, 13)..
# KSD for (logdt, log_b_s_r)=(-3.8380952380952382, -1.75): 5.66
# trying out (8, 14)..
# KSD for (logdt, log_b_s_r)=(-3.7333333333333334, -1.75): 5.72
# trying out (8, 15)..
# KSD for (logdt, log_b_s_r)=(-3.628571428571429, -1.75): 6.09
# trying out (8, 16)..
# KSD for (logdt, log_b_s_r)=(-3.5238095238095237, -1.75): 6.87
# trying out (8, 17)..
# KSD for (logdt, log_b_s_r)=(-3.4190476190476193, -1.75): 12.11
# trying out (8, 18)..
# KSD for (logdt, log_b_s_r)=(-3.3142857142857145, -1.75): 1656.18
# trying out (8, 19)..
# KSD for (logdt, log_b_s_r)=(-3.2095238095238097, -1.75): 2799.39
# trying out (8, 20)..
# KSD for (logdt, log_b_s_r)=(-3.104761904761905, -1.75): 3054.71
# trying out (8, 21)..
# KSD for (logdt, log_b_s_r)=(-3.0, -1.75): 3043.03
# trying out (9, 0)..
# KSD for (logdt, log_b_s_r)=(-5.2, -1.46875): 17.25
# trying out (9, 1)..
# KSD for (logdt, log_b_s_r)=(-5.095238095238096, -1.46875): 15.46
# trying out (9, 2)..
# KSD for (logdt, log_b_s_r)=(-4.9904761904761905, -1.46875): 14.16
# trying out (9, 3)..
# KSD for (logdt, log_b_s_r)=(-4.885714285714286, -1.46875): 12.23
# trying out (9, 4)..
# KSD for (logdt, log_b_s_r)=(-4.780952380952381, -1.46875): 11.38
# trying out (9, 5)..
# KSD for (logdt, log_b_s_r)=(-4.6761904761904765, -1.46875): 10.28
# trying out (9, 6)..
# KSD for (logdt, log_b_s_r)=(-4.571428571428571, -1.46875): 8.97
# trying out (9, 7)..
# KSD for (logdt, log_b_s_r)=(-4.466666666666667, -1.46875): 8.01
# trying out (9, 8)..
# KSD for (logdt, log_b_s_r)=(-4.361904761904762, -1.46875): 7.23
# trying out (9, 9)..
# KSD for (logdt, log_b_s_r)=(-4.257142857142857, -1.46875): 6.53
# trying out (9, 10)..
# KSD for (logdt, log_b_s_r)=(-4.152380952380953, -1.46875): 6.05
# trying out (9, 11)..
# KSD for (logdt, log_b_s_r)=(-4.0476190476190474, -1.46875): 5.61
# trying out (9, 12)..
# KSD for (logdt, log_b_s_r)=(-3.942857142857143, -1.46875): 5.32
# trying out (9, 13)..
# KSD for (logdt, log_b_s_r)=(-3.8380952380952382, -1.46875): 5.36
# trying out (9, 14)..
# KSD for (logdt, log_b_s_r)=(-3.7333333333333334, -1.46875): 5.19
# trying out (9, 15)..
# KSD for (logdt, log_b_s_r)=(-3.628571428571429, -1.46875): 5.43
# trying out (9, 16)..
# KSD for (logdt, log_b_s_r)=(-3.5238095238095237, -1.46875): 5.96
# trying out (9, 17)..
# KSD for (logdt, log_b_s_r)=(-3.4190476190476193, -1.46875): 11.21
# trying out (9, 18)..
# KSD for (logdt, log_b_s_r)=(-3.3142857142857145, -1.46875): 1901.20
# trying out (9, 19)..
# KSD for (logdt, log_b_s_r)=(-3.2095238095238097, -1.46875): 3394.23
# trying out (9, 20)..
# KSD for (logdt, log_b_s_r)=(-3.104761904761905, -1.46875): 3881.18
# trying out (9, 21)..
# KSD for (logdt, log_b_s_r)=(-3.0, -1.46875): 3901.72
# trying out (10, 0)..
# KSD for (logdt, log_b_s_r)=(-5.2, -1.1875): 16.77
# trying out (10, 1)..
# KSD for (logdt, log_b_s_r)=(-5.095238095238096, -1.1875): 13.76
# trying out (10, 2)..
# KSD for (logdt, log_b_s_r)=(-4.9904761904761905, -1.1875): 13.43
# trying out (10, 3)..
# KSD for (logdt, log_b_s_r)=(-4.885714285714286, -1.1875): 10.85
# trying out (10, 4)..
# KSD for (logdt, log_b_s_r)=(-4.780952380952381, -1.1875): 10.31
# trying out (10, 5)..
# KSD for (logdt, log_b_s_r)=(-4.6761904761904765, -1.1875): 9.28
# trying out (10, 6)..
# KSD for (logdt, log_b_s_r)=(-4.571428571428571, -1.1875): 7.92
# trying out (10, 7)..
# KSD for (logdt, log_b_s_r)=(-4.466666666666667, -1.1875): 7.62
# trying out (10, 8)..
# KSD for (logdt, log_b_s_r)=(-4.361904761904762, -1.1875): 7.00
# trying out (10, 9)..
# KSD for (logdt, log_b_s_r)=(-4.257142857142857, -1.1875): 6.32
# trying out (10, 10)..
# KSD for (logdt, log_b_s_r)=(-4.152380952380953, -1.1875): 5.93
# trying out (10, 11)..
# KSD for (logdt, log_b_s_r)=(-4.0476190476190474, -1.1875): 6.46
# trying out (10, 12)..
# KSD for (logdt, log_b_s_r)=(-3.942857142857143, -1.1875): 6.06
# trying out (10, 13)..
# KSD for (logdt, log_b_s_r)=(-3.8380952380952382, -1.1875): 6.24
# trying out (10, 14)..
# KSD for (logdt, log_b_s_r)=(-3.7333333333333334, -1.1875): 6.49
# trying out (10, 15)..
# KSD for (logdt, log_b_s_r)=(-3.628571428571429, -1.1875): 7.04
# trying out (10, 16)..
# KSD for (logdt, log_b_s_r)=(-3.5238095238095237, -1.1875): 7.48
# trying out (10, 17)..
# KSD for (logdt, log_b_s_r)=(-3.4190476190476193, -1.1875): 11.06
# trying out (10, 18)..
# KSD for (logdt, log_b_s_r)=(-3.3142857142857145, -1.1875): 2113.10
# trying out (10, 19)..
# KSD for (logdt, log_b_s_r)=(-3.2095238095238097, -1.1875): 3850.94
# trying out (10, 20)..
# KSD for (logdt, log_b_s_r)=(-3.104761904761905, -1.1875): 4462.11
# trying out (10, 21)..
# KSD for (logdt, log_b_s_r)=(-3.0, -1.1875): 4603.85
# trying out (11, 0)..
# KSD for (logdt, log_b_s_r)=(-5.2, -0.90625): 18.64
# trying out (11, 1)..
# KSD for (logdt, log_b_s_r)=(-5.095238095238096, -0.90625): 17.51
# trying out (11, 2)..
# KSD for (logdt, log_b_s_r)=(-4.9904761904761905, -0.90625): 17.37
# trying out (11, 3)..
# KSD for (logdt, log_b_s_r)=(-4.885714285714286, -0.90625): 16.07
# trying out (11, 4)..
# KSD for (logdt, log_b_s_r)=(-4.780952380952381, -0.90625): 12.16
# trying out (11, 5)..
# KSD for (logdt, log_b_s_r)=(-4.6761904761904765, -0.90625): 12.35
# trying out (11, 6)..
# KSD for (logdt, log_b_s_r)=(-4.571428571428571, -0.90625): 10.41
# trying out (11, 7)..
# KSD for (logdt, log_b_s_r)=(-4.466666666666667, -0.90625): 9.35
# trying out (11, 8)..
# KSD for (logdt, log_b_s_r)=(-4.361904761904762, -0.90625): 8.44
# trying out (11, 9)..
# KSD for (logdt, log_b_s_r)=(-4.257142857142857, -0.90625): 7.38
# trying out (11, 10)..
# KSD for (logdt, log_b_s_r)=(-4.152380952380953, -0.90625): 7.24
# trying out (11, 11)..
# KSD for (logdt, log_b_s_r)=(-4.0476190476190474, -0.90625): 7.16
# trying out (11, 12)..
# KSD for (logdt, log_b_s_r)=(-3.942857142857143, -0.90625): 7.17
# trying out (11, 13)..
# KSD for (logdt, log_b_s_r)=(-3.8380952380952382, -0.90625): 7.89
# trying out (11, 14)..
# KSD for (logdt, log_b_s_r)=(-3.7333333333333334, -0.90625): 8.14
# trying out (11, 15)..
# KSD for (logdt, log_b_s_r)=(-3.628571428571429, -0.90625): 8.45
# trying out (11, 16)..
# KSD for (logdt, log_b_s_r)=(-3.5238095238095237, -0.90625): 9.05
# trying out (11, 17)..
# KSD for (logdt, log_b_s_r)=(-3.4190476190476193, -0.90625): 10.92
# trying out (11, 18)..
# KSD for (logdt, log_b_s_r)=(-3.3142857142857145, -0.90625): 2248.92
# trying out (11, 19)..
# KSD for (logdt, log_b_s_r)=(-3.2095238095238097, -0.90625): 4179.81
# trying out (11, 20)..
# KSD for (logdt, log_b_s_r)=(-3.104761904761905, -0.90625): 4971.04
# trying out (11, 21)..
# KSD for (logdt, log_b_s_r)=(-3.0, -0.90625): 5221.39
# trying out (12, 0)..
# KSD for (logdt, log_b_s_r)=(-5.2, -0.625): 37.40
# trying out (12, 1)..
# KSD for (logdt, log_b_s_r)=(-5.095238095238096, -0.625): 33.06
# trying out (12, 2)..
# KSD for (logdt, log_b_s_r)=(-4.9904761904761905, -0.625): 29.71
# trying out (12, 3)..
# KSD for (logdt, log_b_s_r)=(-4.885714285714286, -0.625): 26.38
# trying out (12, 4)..
# KSD for (logdt, log_b_s_r)=(-4.780952380952381, -0.625): 22.91
# trying out (12, 5)..
# KSD for (logdt, log_b_s_r)=(-4.6761904761904765, -0.625): 18.84
# trying out (12, 6)..
# KSD for (logdt, log_b_s_r)=(-4.571428571428571, -0.625): 18.07
# trying out (12, 7)..
# KSD for (logdt, log_b_s_r)=(-4.466666666666667, -0.625): 16.57
# trying out (12, 8)..
# KSD for (logdt, log_b_s_r)=(-4.361904761904762, -0.625): 14.16
# trying out (12, 9)..
# KSD for (logdt, log_b_s_r)=(-4.257142857142857, -0.625): 12.80
# trying out (12, 10)..
# KSD for (logdt, log_b_s_r)=(-4.152380952380953, -0.625): 12.09
# trying out (12, 11)..
# KSD for (logdt, log_b_s_r)=(-4.0476190476190474, -0.625): 10.90
# trying out (12, 12)..
# KSD for (logdt, log_b_s_r)=(-3.942857142857143, -0.625): 10.35
# trying out (12, 13)..
# KSD for (logdt, log_b_s_r)=(-3.8380952380952382, -0.625): 9.40
# trying out (12, 14)..
# KSD for (logdt, log_b_s_r)=(-3.7333333333333334, -0.625): 10.63
# trying out (12, 15)..
# KSD for (logdt, log_b_s_r)=(-3.628571428571429, -0.625): 10.64
# trying out (12, 16)..
# KSD for (logdt, log_b_s_r)=(-3.5238095238095237, -0.625): 11.05
# trying out (12, 17)..
# KSD for (logdt, log_b_s_r)=(-3.4190476190476193, -0.625): 13.77
# trying out (12, 18)..
# KSD for (logdt, log_b_s_r)=(-3.3142857142857145, -0.625): 2336.90
# trying out (12, 19)..
# KSD for (logdt, log_b_s_r)=(-3.2095238095238097, -0.625): 4351.81
# trying out (12, 20)..
# KSD for (logdt, log_b_s_r)=(-3.104761904761905, -0.625): 5258.02
# trying out (12, 21)..
# KSD for (logdt, log_b_s_r)=(-3.0, -0.625): 5602.24
# trying out (13, 0)..
# KSD for (logdt, log_b_s_r)=(-5.2, -0.34375): 34.91
# trying out (13, 1)..
# KSD for (logdt, log_b_s_r)=(-5.095238095238096, -0.34375): 30.95
# trying out (13, 2)..
# KSD for (logdt, log_b_s_r)=(-4.9904761904761905, -0.34375): 27.19
# trying out (13, 3)..
# KSD for (logdt, log_b_s_r)=(-4.885714285714286, -0.34375): 23.91
# trying out (13, 4)..
# KSD for (logdt, log_b_s_r)=(-4.780952380952381, -0.34375): 20.87
# trying out (13, 5)..
# KSD for (logdt, log_b_s_r)=(-4.6761904761904765, -0.34375): 19.23
# trying out (13, 6)..
# KSD for (logdt, log_b_s_r)=(-4.571428571428571, -0.34375): 16.98
# trying out (13, 7)..
# KSD for (logdt, log_b_s_r)=(-4.466666666666667, -0.34375): 15.08
# trying out (13, 8)..
# KSD for (logdt, log_b_s_r)=(-4.361904761904762, -0.34375): 13.34
# trying out (13, 9)..
# KSD for (logdt, log_b_s_r)=(-4.257142857142857, -0.34375): 11.95
# trying out (13, 10)..
# KSD for (logdt, log_b_s_r)=(-4.152380952380953, -0.34375): 10.75
# trying out (13, 11)..
# KSD for (logdt, log_b_s_r)=(-4.0476190476190474, -0.34375): 10.09
# trying out (13, 12)..
# KSD for (logdt, log_b_s_r)=(-3.942857142857143, -0.34375): 9.93
# trying out (13, 13)..
# KSD for (logdt, log_b_s_r)=(-3.8380952380952382, -0.34375): 11.10
# trying out (13, 14)..
# KSD for (logdt, log_b_s_r)=(-3.7333333333333334, -0.34375): 11.41
# trying out (13, 15)..
# KSD for (logdt, log_b_s_r)=(-3.628571428571429, -0.34375): 10.77
# trying out (13, 16)..
# KSD for (logdt, log_b_s_r)=(-3.5238095238095237, -0.34375): 11.98
# trying out (13, 17)..
# KSD for (logdt, log_b_s_r)=(-3.4190476190476193, -0.34375): 14.28
# trying out (13, 18)..
# KSD for (logdt, log_b_s_r)=(-3.3142857142857145, -0.34375): 2384.20
# trying out (13, 19)..
# KSD for (logdt, log_b_s_r)=(-3.2095238095238097, -0.34375): 4490.69
# trying out (13, 20)..
# KSD for (logdt, log_b_s_r)=(-3.104761904761905, -0.34375): 5489.16
# trying out (13, 21)..
# KSD for (logdt, log_b_s_r)=(-3.0, -0.34375): 5910.55
# trying out (14, 0)..
# KSD for (logdt, log_b_s_r)=(-5.2, -0.0625): 41.88
# trying out (14, 1)..
# KSD for (logdt, log_b_s_r)=(-5.095238095238096, -0.0625): 36.90
# trying out (14, 2)..
# KSD for (logdt, log_b_s_r)=(-4.9904761904761905, -0.0625): 33.21
# trying out (14, 3)..
# KSD for (logdt, log_b_s_r)=(-4.885714285714286, -0.0625): 30.51
# trying out (14, 4)..
# KSD for (logdt, log_b_s_r)=(-4.780952380952381, -0.0625): 26.85
# trying out (14, 5)..
# KSD for (logdt, log_b_s_r)=(-4.6761904761904765, -0.0625): 22.88
# trying out (14, 6)..
# KSD for (logdt, log_b_s_r)=(-4.571428571428571, -0.0625): 21.67
# trying out (14, 7)..
# KSD for (logdt, log_b_s_r)=(-4.466666666666667, -0.0625): 19.28
# trying out (14, 8)..
# KSD for (logdt, log_b_s_r)=(-4.361904761904762, -0.0625): 14.50
# trying out (14, 9)..
# KSD for (logdt, log_b_s_r)=(-4.257142857142857, -0.0625): 12.49
# trying out (14, 10)..
# KSD for (logdt, log_b_s_r)=(-4.152380952380953, -0.0625): 10.98
# trying out (14, 11)..
# KSD for (logdt, log_b_s_r)=(-4.0476190476190474, -0.0625): 9.61
# trying out (14, 12)..
# KSD for (logdt, log_b_s_r)=(-3.942857142857143, -0.0625): 8.76
# trying out (14, 13)..
# KSD for (logdt, log_b_s_r)=(-3.8380952380952382, -0.0625): 9.72
# trying out (14, 14)..
# KSD for (logdt, log_b_s_r)=(-3.7333333333333334, -0.0625): 10.11
# trying out (14, 15)..
# KSD for (logdt, log_b_s_r)=(-3.628571428571429, -0.0625): 10.03
# trying out (14, 16)..
# KSD for (logdt, log_b_s_r)=(-3.5238095238095237, -0.0625): 10.75
# trying out (14, 17)..
# KSD for (logdt, log_b_s_r)=(-3.4190476190476193, -0.0625): 16.36
# trying out (14, 18)..
# KSD for (logdt, log_b_s_r)=(-3.3142857142857145, -0.0625): 2370.70
# trying out (14, 19)..
# KSD for (logdt, log_b_s_r)=(-3.2095238095238097, -0.0625): 4482.26
# trying out (14, 20)..
# KSD for (logdt, log_b_s_r)=(-3.104761904761905, -0.0625): 5571.24
# trying out (14, 21)..
# KSD for (logdt, log_b_s_r)=(-3.0, -0.0625): 6051.25
# trying out (15, 0)..
# KSD for (logdt, log_b_s_r)=(-5.2, 0.21875): 67.48
# trying out (15, 1)..
# KSD for (logdt, log_b_s_r)=(-5.095238095238096, 0.21875): 67.40
# trying out (15, 2)..
# KSD for (logdt, log_b_s_r)=(-4.9904761904761905, 0.21875): 59.24
# trying out (15, 3)..
# KSD for (logdt, log_b_s_r)=(-4.885714285714286, 0.21875): 51.74
# trying out (15, 4)..
# KSD for (logdt, log_b_s_r)=(-4.780952380952381, 0.21875): 45.26
# trying out (15, 5)..
# KSD for (logdt, log_b_s_r)=(-4.6761904761904765, 0.21875): 40.85
# trying out (15, 6)..
# KSD for (logdt, log_b_s_r)=(-4.571428571428571, 0.21875): 36.16
# trying out (15, 7)..
# KSD for (logdt, log_b_s_r)=(-4.466666666666667, 0.21875): 32.15
# trying out (15, 8)..
# KSD for (logdt, log_b_s_r)=(-4.361904761904762, 0.21875): 27.57
# trying out (15, 9)..
# KSD for (logdt, log_b_s_r)=(-4.257142857142857, 0.21875): 24.62
# trying out (15, 10)..
# KSD for (logdt, log_b_s_r)=(-4.152380952380953, 0.21875): 22.40
# trying out (15, 11)..
# KSD for (logdt, log_b_s_r)=(-4.0476190476190474, 0.21875): 20.90
# trying out (15, 12)..
# KSD for (logdt, log_b_s_r)=(-3.942857142857143, 0.21875): 20.19
# trying out (15, 13)..
# KSD for (logdt, log_b_s_r)=(-3.8380952380952382, 0.21875): 18.75
# trying out (15, 14)..
# KSD for (logdt, log_b_s_r)=(-3.7333333333333334, 0.21875): 17.91
# trying out (15, 15)..
# KSD for (logdt, log_b_s_r)=(-3.628571428571429, 0.21875): 16.97
# trying out (15, 16)..
# KSD for (logdt, log_b_s_r)=(-3.5238095238095237, 0.21875): 16.33
# trying out (15, 17)..
# KSD for (logdt, log_b_s_r)=(-3.4190476190476193, 0.21875): 18.98
# trying out (15, 18)..
# KSD for (logdt, log_b_s_r)=(-3.3142857142857145, 0.21875): 2325.03
# trying out (15, 19)..
# KSD for (logdt, log_b_s_r)=(-3.2095238095238097, 0.21875): 4435.26
# trying out (15, 20)..
# KSD for (logdt, log_b_s_r)=(-3.104761904761905, 0.21875): 5472.22
# trying out (15, 21)..
# KSD for (logdt, log_b_s_r)=(-3.0, 0.21875): 6037.36
# trying out (16, 0)..
# KSD for (logdt, log_b_s_r)=(-5.2, 0.5): 67.02
# trying out (16, 1)..
# KSD for (logdt, log_b_s_r)=(-5.095238095238096, 0.5): 59.01
# trying out (16, 2)..
# KSD for (logdt, log_b_s_r)=(-4.9904761904761905, 0.5): 53.03
# trying out (16, 3)..
# KSD for (logdt, log_b_s_r)=(-4.885714285714286, 0.5): 47.27
# trying out (16, 4)..
# KSD for (logdt, log_b_s_r)=(-4.780952380952381, 0.5): 41.46
# trying out (16, 5)..
# KSD for (logdt, log_b_s_r)=(-4.6761904761904765, 0.5): 36.32
# trying out (16, 6)..
# KSD for (logdt, log_b_s_r)=(-4.571428571428571, 0.5): 36.40
# trying out (16, 7)..
# KSD for (logdt, log_b_s_r)=(-4.466666666666667, 0.5): 28.45
# trying out (16, 8)..
# KSD for (logdt, log_b_s_r)=(-4.361904761904762, 0.5): 23.91
# trying out (16, 9)..
# KSD for (logdt, log_b_s_r)=(-4.257142857142857, 0.5): 21.50
# trying out (16, 10)..
# KSD for (logdt, log_b_s_r)=(-4.152380952380953, 0.5): 18.74
# trying out (16, 11)..
# KSD for (logdt, log_b_s_r)=(-4.0476190476190474, 0.5): 16.57
# trying out (16, 12)..
# KSD for (logdt, log_b_s_r)=(-3.942857142857143, 0.5): 14.67
# trying out (16, 13)..
# KSD for (logdt, log_b_s_r)=(-3.8380952380952382, 0.5): 12.93
# trying out (16, 14)..
# KSD for (logdt, log_b_s_r)=(-3.7333333333333334, 0.5): 12.11
# trying out (16, 15)..
# KSD for (logdt, log_b_s_r)=(-3.628571428571429, 0.5): 12.31
# trying out (16, 16)..
# KSD for (logdt, log_b_s_r)=(-3.5238095238095237, 0.5): 14.18
# trying out (16, 17)..
# KSD for (logdt, log_b_s_r)=(-3.4190476190476193, 0.5): 31.11
# trying out (16, 18)..
# KSD for (logdt, log_b_s_r)=(-3.3142857142857145, 0.5): 2261.51
# trying out (16, 19)..
# KSD for (logdt, log_b_s_r)=(-3.2095238095238097, 0.5): 4135.65
# trying out (16, 20)..
# KSD for (logdt, log_b_s_r)=(-3.104761904761905, 0.5): 5147.90
# trying out (16, 21)..
# KSD for (logdt, log_b_s_r)=(-3.0, 0.5): 5721.12
# Done.
#
# Running sgld for a time budget of 5 sec..
# trying out (0, 0)..
# KSD for (logdt, log_b_s_r)=(-5.3, -2.2): 19.54
# trying out (0, 1)..
# KSD for (logdt, log_b_s_r)=(-5.219047619047619, -2.2): 21.46
# trying out (0, 2)..
# KSD for (logdt, log_b_s_r)=(-5.138095238095238, -2.2): 16.87
# trying out (0, 3)..
# KSD for (logdt, log_b_s_r)=(-5.057142857142857, -2.2): 18.24
# trying out (0, 4)..
# KSD for (logdt, log_b_s_r)=(-4.976190476190476, -2.2): 17.91
# trying out (0, 5)..
# KSD for (logdt, log_b_s_r)=(-4.895238095238095, -2.2): 17.84
# trying out (0, 6)..
# KSD for (logdt, log_b_s_r)=(-4.814285714285714, -2.2): 19.61
# trying out (0, 7)..
# KSD for (logdt, log_b_s_r)=(-4.733333333333333, -2.2): 21.40
# trying out (0, 8)..
# KSD for (logdt, log_b_s_r)=(-4.652380952380952, -2.2): 22.90
# trying out (0, 9)..
# KSD for (logdt, log_b_s_r)=(-4.571428571428571, -2.2): 26.79
# trying out (0, 10)..
# KSD for (logdt, log_b_s_r)=(-4.4904761904761905, -2.2): 30.61
# trying out (0, 11)..
# KSD for (logdt, log_b_s_r)=(-4.40952380952381, -2.2): 35.80
# trying out (0, 12)..
# KSD for (logdt, log_b_s_r)=(-4.328571428571428, -2.2): 41.99
# trying out (0, 13)..
# KSD for (logdt, log_b_s_r)=(-4.247619047619048, -2.2): 50.59
# trying out (0, 14)..
# KSD for (logdt, log_b_s_r)=(-4.166666666666666, -2.2): 60.50
# trying out (0, 15)..
# KSD for (logdt, log_b_s_r)=(-4.085714285714285, -2.2): 73.67
# trying out (0, 16)..
# KSD for (logdt, log_b_s_r)=(-4.004761904761905, -2.2): 89.95
# trying out (0, 17)..
# KSD for (logdt, log_b_s_r)=(-3.923809523809524, -2.2): 110.34
# trying out (0, 18)..
# KSD for (logdt, log_b_s_r)=(-3.842857142857143, -2.2): 137.48
# trying out (0, 19)..
# KSD for (logdt, log_b_s_r)=(-3.761904761904762, -2.2): 173.00
# trying out (0, 20)..
# KSD for (logdt, log_b_s_r)=(-3.680952380952381, -2.2): 222.64
# trying out (0, 21)..
# KSD for (logdt, log_b_s_r)=(-3.6, -2.2): 295.53
# trying out (1, 0)..
# KSD for (logdt, log_b_s_r)=(-5.3, -2.0625): 17.22
# trying out (1, 1)..
# KSD for (logdt, log_b_s_r)=(-5.219047619047619, -2.0625): 16.13
# trying out (1, 2)..
# KSD for (logdt, log_b_s_r)=(-5.138095238095238, -2.0625): 14.13
# trying out (1, 3)..
# KSD for (logdt, log_b_s_r)=(-5.057142857142857, -2.0625): 13.39
# trying out (1, 4)..
# KSD for (logdt, log_b_s_r)=(-4.976190476190476, -2.0625): 14.15
# trying out (1, 5)..
# KSD for (logdt, log_b_s_r)=(-4.895238095238095, -2.0625): 13.99
# trying out (1, 6)..
# KSD for (logdt, log_b_s_r)=(-4.814285714285714, -2.0625): 14.42
# trying out (1, 7)..
# KSD for (logdt, log_b_s_r)=(-4.733333333333333, -2.0625): 15.40
# trying out (1, 8)..
# KSD for (logdt, log_b_s_r)=(-4.652380952380952, -2.0625): 16.73
# trying out (1, 9)..
# KSD for (logdt, log_b_s_r)=(-4.571428571428571, -2.0625): 18.99
# trying out (1, 10)..
# KSD for (logdt, log_b_s_r)=(-4.4904761904761905, -2.0625): 21.74
# trying out (1, 11)..
# KSD for (logdt, log_b_s_r)=(-4.40952380952381, -2.0625): 25.31
# trying out (1, 12)..
# KSD for (logdt, log_b_s_r)=(-4.328571428571428, -2.0625): 30.15
# trying out (1, 13)..
# KSD for (logdt, log_b_s_r)=(-4.247619047619048, -2.0625): 36.01
# trying out (1, 14)..
# KSD for (logdt, log_b_s_r)=(-4.166666666666666, -2.0625): 43.70
# trying out (1, 15)..
# KSD for (logdt, log_b_s_r)=(-4.085714285714285, -2.0625): 53.26
# trying out (1, 16)..
# KSD for (logdt, log_b_s_r)=(-4.004761904761905, -2.0625): 65.27
# trying out (1, 17)..
# KSD for (logdt, log_b_s_r)=(-3.923809523809524, -2.0625): 81.37
# trying out (1, 18)..
# KSD for (logdt, log_b_s_r)=(-3.842857142857143, -2.0625): 102.01
# trying out (1, 19)..
# KSD for (logdt, log_b_s_r)=(-3.761904761904762, -2.0625): 130.14
# trying out (1, 20)..
# KSD for (logdt, log_b_s_r)=(-3.680952380952381, -2.0625): 169.99
# trying out (1, 21)..
# KSD for (logdt, log_b_s_r)=(-3.6, -2.0625): 229.63
# trying out (2, 0)..
# KSD for (logdt, log_b_s_r)=(-5.3, -1.9250000000000003): 14.22
# trying out (2, 1)..
# KSD for (logdt, log_b_s_r)=(-5.219047619047619, -1.9250000000000003): 13.30
# trying out (2, 2)..
# KSD for (logdt, log_b_s_r)=(-5.138095238095238, -1.9250000000000003): 12.67
# trying out (2, 3)..
# KSD for (logdt, log_b_s_r)=(-5.057142857142857, -1.9250000000000003): 12.42
# trying out (2, 4)..
# KSD for (logdt, log_b_s_r)=(-4.976190476190476, -1.9250000000000003): 12.59
# trying out (2, 5)..
# KSD for (logdt, log_b_s_r)=(-4.895238095238095, -1.9250000000000003): 12.60
# trying out (2, 6)..
# KSD for (logdt, log_b_s_r)=(-4.814285714285714, -1.9250000000000003): 13.05
# trying out (2, 7)..
# KSD for (logdt, log_b_s_r)=(-4.733333333333333, -1.9250000000000003): 13.65
# trying out (2, 8)..
# KSD for (logdt, log_b_s_r)=(-4.652380952380952, -1.9250000000000003): 14.75
# trying out (2, 9)..
# KSD for (logdt, log_b_s_r)=(-4.571428571428571, -1.9250000000000003): 16.14
# trying out (2, 10)..
# KSD for (logdt, log_b_s_r)=(-4.4904761904761905, -1.9250000000000003): 17.96
# trying out (2, 11)..
# KSD for (logdt, log_b_s_r)=(-4.40952380952381, -1.9250000000000003): 20.51
# trying out (2, 12)..
# KSD for (logdt, log_b_s_r)=(-4.328571428571428, -1.9250000000000003): 23.58
# trying out (2, 13)..
# KSD for (logdt, log_b_s_r)=(-4.247619047619048, -1.9250000000000003): 27.72
# trying out (2, 14)..
# KSD for (logdt, log_b_s_r)=(-4.166666666666666, -1.9250000000000003): 33.44
# trying out (2, 15)..
# KSD for (logdt, log_b_s_r)=(-4.085714285714285, -1.9250000000000003): 40.03
# trying out (2, 16)..
# KSD for (logdt, log_b_s_r)=(-4.004761904761905, -1.9250000000000003): 48.91
# trying out (2, 17)..
# KSD for (logdt, log_b_s_r)=(-3.923809523809524, -1.9250000000000003): 60.61
# trying out (2, 18)..
# KSD for (logdt, log_b_s_r)=(-3.842857142857143, -1.9250000000000003): 76.41
# trying out (2, 19)..
# KSD for (logdt, log_b_s_r)=(-3.761904761904762, -1.9250000000000003): 97.77
# trying out (2, 20)..
# KSD for (logdt, log_b_s_r)=(-3.680952380952381, -1.9250000000000003): 129.25
# trying out (2, 21)..
# KSD for (logdt, log_b_s_r)=(-3.6, -1.9250000000000003): 177.71
# trying out (3, 0)..
# KSD for (logdt, log_b_s_r)=(-5.3, -1.7875): 17.03
# trying out (3, 1)..
# KSD for (logdt, log_b_s_r)=(-5.219047619047619, -1.7875): 15.08
# trying out (3, 2)..
# KSD for (logdt, log_b_s_r)=(-5.138095238095238, -1.7875): 14.95
# trying out (3, 3)..
# KSD for (logdt, log_b_s_r)=(-5.057142857142857, -1.7875): 14.12
# trying out (3, 4)..
# KSD for (logdt, log_b_s_r)=(-4.976190476190476, -1.7875): 12.54
# trying out (3, 5)..
# KSD for (logdt, log_b_s_r)=(-4.895238095238095, -1.7875): 12.81
# trying out (3, 6)..
# KSD for (logdt, log_b_s_r)=(-4.814285714285714, -1.7875): 11.65
# trying out (3, 7)..
# KSD for (logdt, log_b_s_r)=(-4.733333333333333, -1.7875): 12.38
# trying out (3, 8)..
# KSD for (logdt, log_b_s_r)=(-4.652380952380952, -1.7875): 12.05
# trying out (3, 9)..
# KSD for (logdt, log_b_s_r)=(-4.571428571428571, -1.7875): 12.90
# trying out (3, 10)..
# KSD for (logdt, log_b_s_r)=(-4.4904761904761905, -1.7875): 13.42
# trying out (3, 11)..
# KSD for (logdt, log_b_s_r)=(-4.40952380952381, -1.7875): 15.60
# trying out (3, 12)..
# KSD for (logdt, log_b_s_r)=(-4.328571428571428, -1.7875): 17.50
# trying out (3, 13)..
# KSD for (logdt, log_b_s_r)=(-4.247619047619048, -1.7875): 20.47
# trying out (3, 14)..
# KSD for (logdt, log_b_s_r)=(-4.166666666666666, -1.7875): 24.38
# trying out (3, 15)..
# KSD for (logdt, log_b_s_r)=(-4.085714285714285, -1.7875): 29.31
# trying out (3, 16)..
# KSD for (logdt, log_b_s_r)=(-4.004761904761905, -1.7875): 35.89
# trying out (3, 17)..
# KSD for (logdt, log_b_s_r)=(-3.923809523809524, -1.7875): 44.48
# trying out (3, 18)..
# KSD for (logdt, log_b_s_r)=(-3.842857142857143, -1.7875): 56.02
# trying out (3, 19)..
# KSD for (logdt, log_b_s_r)=(-3.761904761904762, -1.7875): 72.06
# trying out (3, 20)..
# KSD for (logdt, log_b_s_r)=(-3.680952380952381, -1.7875): 95.62
# trying out (3, 21)..
# KSD for (logdt, log_b_s_r)=(-3.6, -1.7875): 132.50
# trying out (4, 0)..
# KSD for (logdt, log_b_s_r)=(-5.3, -1.6500000000000001): 14.61
# trying out (4, 1)..
# KSD for (logdt, log_b_s_r)=(-5.219047619047619, -1.6500000000000001): 13.24
# trying out (4, 2)..
# KSD for (logdt, log_b_s_r)=(-5.138095238095238, -1.6500000000000001): 11.74
# trying out (4, 3)..
# KSD for (logdt, log_b_s_r)=(-5.057142857142857, -1.6500000000000001): 10.79
# trying out (4, 4)..
# KSD for (logdt, log_b_s_r)=(-4.976190476190476, -1.6500000000000001): 9.90
# trying out (4, 5)..
# KSD for (logdt, log_b_s_r)=(-4.895238095238095, -1.6500000000000001): 9.13
# trying out (4, 6)..
# KSD for (logdt, log_b_s_r)=(-4.814285714285714, -1.6500000000000001): 8.61
# trying out (4, 7)..
# KSD for (logdt, log_b_s_r)=(-4.733333333333333, -1.6500000000000001): 8.52
# trying out (4, 8)..
# KSD for (logdt, log_b_s_r)=(-4.652380952380952, -1.6500000000000001): 8.84
# trying out (4, 9)..
# KSD for (logdt, log_b_s_r)=(-4.571428571428571, -1.6500000000000001): 9.20
# trying out (4, 10)..
# KSD for (logdt, log_b_s_r)=(-4.4904761904761905, -1.6500000000000001): 9.97
# trying out (4, 11)..
# KSD for (logdt, log_b_s_r)=(-4.40952380952381, -1.6500000000000001): 11.17
# trying out (4, 12)..
# KSD for (logdt, log_b_s_r)=(-4.328571428571428, -1.6500000000000001): 12.55
# trying out (4, 13)..
# KSD for (logdt, log_b_s_r)=(-4.247619047619048, -1.6500000000000001): 15.08
# trying out (4, 14)..
# KSD for (logdt, log_b_s_r)=(-4.166666666666666, -1.6500000000000001): 17.90
# trying out (4, 15)..
# KSD for (logdt, log_b_s_r)=(-4.085714285714285, -1.6500000000000001): 22.09
# trying out (4, 16)..
# KSD for (logdt, log_b_s_r)=(-4.004761904761905, -1.6500000000000001): 27.14
# trying out (4, 17)..
# KSD for (logdt, log_b_s_r)=(-3.923809523809524, -1.6500000000000001): 34.34
# trying out (4, 18)..
# KSD for (logdt, log_b_s_r)=(-3.842857142857143, -1.6500000000000001): 43.40
# trying out (4, 19)..
# KSD for (logdt, log_b_s_r)=(-3.761904761904762, -1.6500000000000001): 55.96
# trying out (4, 20)..
# KSD for (logdt, log_b_s_r)=(-3.680952380952381, -1.6500000000000001): 74.48
# trying out (4, 21)..
# KSD for (logdt, log_b_s_r)=(-3.6, -1.6500000000000001): 103.10
# trying out (5, 0)..
# KSD for (logdt, log_b_s_r)=(-5.3, -1.5125000000000002): 20.63
# trying out (5, 1)..
# KSD for (logdt, log_b_s_r)=(-5.219047619047619, -1.5125000000000002): 19.72
# trying out (5, 2)..
# KSD for (logdt, log_b_s_r)=(-5.138095238095238, -1.5125000000000002): 19.61
# trying out (5, 3)..
# KSD for (logdt, log_b_s_r)=(-5.057142857142857, -1.5125000000000002): 17.67
# trying out (5, 4)..
# KSD for (logdt, log_b_s_r)=(-4.976190476190476, -1.5125000000000002): 16.28
# trying out (5, 5)..
# KSD for (logdt, log_b_s_r)=(-4.895238095238095, -1.5125000000000002): 15.41
# trying out (5, 6)..
# KSD for (logdt, log_b_s_r)=(-4.814285714285714, -1.5125000000000002): 15.11
# trying out (5, 7)..
# KSD for (logdt, log_b_s_r)=(-4.733333333333333, -1.5125000000000002): 14.11
# trying out (5, 8)..
# KSD for (logdt, log_b_s_r)=(-4.652380952380952, -1.5125000000000002): 13.76
# trying out (5, 9)..
# KSD for (logdt, log_b_s_r)=(-4.571428571428571, -1.5125000000000002): 13.67
# trying out (5, 10)..
# KSD for (logdt, log_b_s_r)=(-4.4904761904761905, -1.5125000000000002): 13.48
# trying out (5, 11)..
# KSD for (logdt, log_b_s_r)=(-4.40952380952381, -1.5125000000000002): 13.63
# trying out (5, 12)..
# KSD for (logdt, log_b_s_r)=(-4.328571428571428, -1.5125000000000002): 14.25
# trying out (5, 13)..
# KSD for (logdt, log_b_s_r)=(-4.247619047619048, -1.5125000000000002): 14.99
# trying out (5, 14)..
# KSD for (logdt, log_b_s_r)=(-4.166666666666666, -1.5125000000000002): 16.06
# trying out (5, 15)..
# KSD for (logdt, log_b_s_r)=(-4.085714285714285, -1.5125000000000002): 18.31
# trying out (5, 16)..
# KSD for (logdt, log_b_s_r)=(-4.004761904761905, -1.5125000000000002): 21.64
# trying out (5, 17)..
# KSD for (logdt, log_b_s_r)=(-3.923809523809524, -1.5125000000000002): 26.08
# trying out (5, 18)..
# KSD for (logdt, log_b_s_r)=(-3.842857142857143, -1.5125000000000002): 32.13
# trying out (5, 19)..
# KSD for (logdt, log_b_s_r)=(-3.761904761904762, -1.5125000000000002): 41.29
# trying out (5, 20)..
# KSD for (logdt, log_b_s_r)=(-3.680952380952381, -1.5125000000000002): 54.54
# trying out (5, 21)..
# KSD for (logdt, log_b_s_r)=(-3.6, -1.5125000000000002): 75.95
# trying out (6, 0)..
# KSD for (logdt, log_b_s_r)=(-5.3, -1.375): 23.62
# trying out (6, 1)..
# KSD for (logdt, log_b_s_r)=(-5.219047619047619, -1.375): 21.77
# trying out (6, 2)..
# KSD for (logdt, log_b_s_r)=(-5.138095238095238, -1.375): 20.82
# trying out (6, 3)..
# KSD for (logdt, log_b_s_r)=(-5.057142857142857, -1.375): 19.84
# trying out (6, 4)..
# KSD for (logdt, log_b_s_r)=(-4.976190476190476, -1.375): 18.38
# trying out (6, 5)..
# KSD for (logdt, log_b_s_r)=(-4.895238095238095, -1.375): 17.56
# trying out (6, 6)..
# KSD for (logdt, log_b_s_r)=(-4.814285714285714, -1.375): 16.06
# trying out (6, 7)..
# KSD for (logdt, log_b_s_r)=(-4.733333333333333, -1.375): 15.92
# trying out (6, 8)..
# KSD for (logdt, log_b_s_r)=(-4.652380952380952, -1.375): 14.76
# trying out (6, 9)..
# KSD for (logdt, log_b_s_r)=(-4.571428571428571, -1.375): 14.27
# trying out (6, 10)..
# KSD for (logdt, log_b_s_r)=(-4.4904761904761905, -1.375): 13.42
# trying out (6, 11)..
# KSD for (logdt, log_b_s_r)=(-4.40952380952381, -1.375): 13.80
# trying out (6, 12)..
# KSD for (logdt, log_b_s_r)=(-4.328571428571428, -1.375): 13.21
# trying out (6, 13)..
# KSD for (logdt, log_b_s_r)=(-4.247619047619048, -1.375): 13.77
# trying out (6, 14)..
# KSD for (logdt, log_b_s_r)=(-4.166666666666666, -1.375): 14.28
# trying out (6, 15)..
# KSD for (logdt, log_b_s_r)=(-4.085714285714285, -1.375): 15.11
# trying out (6, 16)..
# KSD for (logdt, log_b_s_r)=(-4.004761904761905, -1.375): 17.03
# trying out (6, 17)..
# KSD for (logdt, log_b_s_r)=(-3.923809523809524, -1.375): 19.93
# trying out (6, 18)..
# KSD for (logdt, log_b_s_r)=(-3.842857142857143, -1.375): 24.12
# trying out (6, 19)..
# KSD for (logdt, log_b_s_r)=(-3.761904761904762, -1.375): 30.21
# trying out (6, 20)..
# KSD for (logdt, log_b_s_r)=(-3.680952380952381, -1.375): 40.21
# trying out (6, 21)..
# KSD for (logdt, log_b_s_r)=(-3.6, -1.375): 56.35
# trying out (7, 0)..
# KSD for (logdt, log_b_s_r)=(-5.3, -1.2375): 25.22
# trying out (7, 1)..
# KSD for (logdt, log_b_s_r)=(-5.219047619047619, -1.2375): 24.50
# trying out (7, 2)..
# KSD for (logdt, log_b_s_r)=(-5.138095238095238, -1.2375): 22.70
# trying out (7, 3)..
# KSD for (logdt, log_b_s_r)=(-5.057142857142857, -1.2375): 21.65
# trying out (7, 4)..
# KSD for (logdt, log_b_s_r)=(-4.976190476190476, -1.2375): 20.21
# trying out (7, 5)..
# KSD for (logdt, log_b_s_r)=(-4.895238095238095, -1.2375): 19.23
# trying out (7, 6)..
# KSD for (logdt, log_b_s_r)=(-4.814285714285714, -1.2375): 18.26
# trying out (7, 7)..
# KSD for (logdt, log_b_s_r)=(-4.733333333333333, -1.2375): 16.26
# trying out (7, 8)..
# KSD for (logdt, log_b_s_r)=(-4.652380952380952, -1.2375): 16.62
# trying out (7, 9)..
# KSD for (logdt, log_b_s_r)=(-4.571428571428571, -1.2375): 14.45
# trying out (7, 10)..
# KSD for (logdt, log_b_s_r)=(-4.4904761904761905, -1.2375): 15.62
# trying out (7, 11)..
# KSD for (logdt, log_b_s_r)=(-4.40952380952381, -1.2375): 13.43
# trying out (7, 12)..
# KSD for (logdt, log_b_s_r)=(-4.328571428571428, -1.2375): 14.28
# trying out (7, 13)..
# KSD for (logdt, log_b_s_r)=(-4.247619047619048, -1.2375): 13.17
# trying out (7, 14)..
# KSD for (logdt, log_b_s_r)=(-4.166666666666666, -1.2375): 14.19
# trying out (7, 15)..
# KSD for (logdt, log_b_s_r)=(-4.085714285714285, -1.2375): 14.14
# trying out (7, 16)..
# KSD for (logdt, log_b_s_r)=(-4.004761904761905, -1.2375): 15.80
# trying out (7, 17)..
# KSD for (logdt, log_b_s_r)=(-3.923809523809524, -1.2375): 17.20
# trying out (7, 18)..
# KSD for (logdt, log_b_s_r)=(-3.842857142857143, -1.2375): 20.46
# trying out (7, 19)..
# KSD for (logdt, log_b_s_r)=(-3.761904761904762, -1.2375): 24.46
# trying out (7, 20)..
# KSD for (logdt, log_b_s_r)=(-3.680952380952381, -1.2375): 31.85
# trying out (7, 21)..
# KSD for (logdt, log_b_s_r)=(-3.6, -1.2375): 43.01
# trying out (8, 0)..
# KSD for (logdt, log_b_s_r)=(-5.3, -1.1): 16.39
# trying out (8, 1)..
# KSD for (logdt, log_b_s_r)=(-5.219047619047619, -1.1): 15.50
# trying out (8, 2)..
# KSD for (logdt, log_b_s_r)=(-5.138095238095238, -1.1): 15.01
# trying out (8, 3)..
# KSD for (logdt, log_b_s_r)=(-5.057142857142857, -1.1): 13.54
# trying out (8, 4)..
# KSD for (logdt, log_b_s_r)=(-4.976190476190476, -1.1): 11.93
# trying out (8, 5)..
# KSD for (logdt, log_b_s_r)=(-4.895238095238095, -1.1): 11.43
# trying out (8, 6)..
# KSD for (logdt, log_b_s_r)=(-4.814285714285714, -1.1): 10.72
# trying out (8, 7)..
# KSD for (logdt, log_b_s_r)=(-4.733333333333333, -1.1): 9.29
# trying out (8, 8)..
# KSD for (logdt, log_b_s_r)=(-4.652380952380952, -1.1): 9.02
# trying out (8, 9)..
# KSD for (logdt, log_b_s_r)=(-4.571428571428571, -1.1): 8.62
# trying out (8, 10)..
# KSD for (logdt, log_b_s_r)=(-4.4904761904761905, -1.1): 7.97
# trying out (8, 11)..
# KSD for (logdt, log_b_s_r)=(-4.40952380952381, -1.1): 7.67
# trying out (8, 12)..
# KSD for (logdt, log_b_s_r)=(-4.328571428571428, -1.1): 7.29
# trying out (8, 13)..
# KSD for (logdt, log_b_s_r)=(-4.247619047619048, -1.1): 7.23
# trying out (8, 14)..
# ...
# KSD for (logdt, log_b_s_r)=(-5.3, -0.9625000000000001): 24.03
# trying out (9, 1)..
# KSD for (logdt, log_b_s_r)=(-5.219047619047619, -0.9625000000000001): 22.35
# trying out (9, 2)..
# KSD for (logdt, log_b_s_r)=(-5.138095238095238, -0.9625000000000001): 20.54
# trying out (9, 3)..
# KSD for (logdt, log_b_s_r)=(-5.057142857142857, -0.9625000000000001): 18.94
# trying out (9, 4)..
# KSD for (logdt, log_b_s_r)=(-4.976190476190476, -0.9625000000000001): 17.38
# trying out (9, 5)..
# KSD for (logdt, log_b_s_r)=(-4.895238095238095, -0.9625000000000001): 16.09
# trying out (9, 6)..
# KSD for (logdt, log_b_s_r)=(-4.814285714285714, -0.9625000000000001): 15.10
# trying out (9, 7)..
# KSD for (logdt, log_b_s_r)=(-4.733333333333333, -0.9625000000000001): 14.40
# trying out (9, 8)..
# KSD for (logdt, log_b_s_r)=(-4.652380952380952, -0.9625000000000001): 13.38
# trying out (9, 9)..
# KSD for (logdt, log_b_s_r)=(-4.571428571428571, -0.9625000000000001): 12.98
# trying out (9, 10)..
# KSD for (logdt, log_b_s_r)=(-4.4904761904761905, -0.9625000000000001): 12.38
# trying out (9, 11)..
# KSD for (logdt, log_b_s_r)=(-4.40952380952381, -0.9625000000000001): 12.09
# trying out (9, 12)..
# KSD for (logdt, log_b_s_r)=(-4.328571428571428, -0.9625000000000001): 11.61
# trying out (9, 13)..
# KSD for (logdt, log_b_s_r)=(-4.247619047619048, -0.9625000000000001): 11.38
# trying out (9, 14)..
# KSD for (logdt, log_b_s_r)=(-4.166666666666666, -0.9625000000000001): 11.85
# trying out (9, 15)..
# KSD for (logdt, log_b_s_r)=(-4.085714285714285, -0.9625000000000001): 11.82
# trying out (9, 16)..
# KSD for (logdt, log_b_s_r)=(-4.004761904761905, -0.9625000000000001): 12.75
# trying out (9, 17)..
# KSD for (logdt, log_b_s_r)=(-3.923809523809524, -0.9625000000000001): 14.17
# trying out (9, 18)..
# KSD for (logdt, log_b_s_r)=(-3.842857142857143, -0.9625000000000001): 15.44
# trying out (9, 19)..
# KSD for (logdt, log_b_s_r)=(-3.761904761904762, -0.9625000000000001): 18.69
# trying out (9, 20)..
# KSD for (logdt, log_b_s_r)=(-3.680952380952381, -0.9625000000000001): 20.90
# trying out (9, 21)..
# KSD for (logdt, log_b_s_r)=(-3.6, -0.9625000000000001): 28.44
# trying out (10, 0)..
# KSD for (logdt, log_b_s_r)=(-5.3, -0.8250000000000002): 19.79
# trying out (10, 1)..
# KSD for (logdt, log_b_s_r)=(-5.219047619047619, -0.8250000000000002): 18.25
# trying out (10, 2)..
# KSD for (logdt, log_b_s_r)=(-5.138095238095238, -0.8250000000000002): 18.74
# trying out (10, 3)..
# KSD for (logdt, log_b_s_r)=(-5.057142857142857, -0.8250000000000002): 14.28
# trying out (10, 4)..
# KSD for (logdt, log_b_s_r)=(-4.976190476190476, -0.8250000000000002): 14.62
# trying out (10, 5)..
# KSD for (logdt, log_b_s_r)=(-4.895238095238095, -0.8250000000000002): 12.17
# trying out (10, 6)..
# KSD for (logdt, log_b_s_r)=(-4.814285714285714, -0.8250000000000002): 11.97
# trying out (10, 7)..
# KSD for (logdt, log_b_s_r)=(-4.733333333333333, -0.8250000000000002): 11.26
# trying out (10, 8)..
# KSD for (logdt, log_b_s_r)=(-4.652380952380952, -0.8250000000000002): 9.69
# trying out (10, 9)..
# KSD for (logdt, log_b_s_r)=(-4.571428571428571, -0.8250000000000002): 9.96
# trying out (10, 10)..
# KSD for (logdt, log_b_s_r)=(-4.4904761904761905, -0.8250000000000002): 9.06
# trying out (10, 11)..
# KSD for (logdt, log_b_s_r)=(-4.40952380952381, -0.8250000000000002): 8.49
# trying out (10, 12)..
# KSD for (logdt, log_b_s_r)=(-4.328571428571428, -0.8250000000000002): 7.83
# trying out (10, 13)..
# KSD for (logdt, log_b_s_r)=(-4.247619047619048, -0.8250000000000002): 7.88
# trying out (10, 14)..
# KSD for (logdt, log_b_s_r)=(-4.166666666666666, -0.8250000000000002): 7.91
# trying out (10, 15)..
# KSD for (logdt, log_b_s_r)=(-4.085714285714285, -0.8250000000000002): 7.26
# trying out (10, 16)..
# KSD for (logdt, log_b_s_r)=(-4.004761904761905, -0.8250000000000002): 8.45
# trying out (10, 17)..
# KSD for (logdt, log_b_s_r)=(-3.923809523809524, -0.8250000000000002): 9.82
# trying out (10, 18)..
# KSD for (logdt, log_b_s_r)=(-3.842857142857143, -0.8250000000000002): 10.98
# trying out (10, 19)..
# KSD for (logdt, log_b_s_r)=(-3.761904761904762, -0.8250000000000002): 13.57
# trying out (10, 20)..
# KSD for (logdt, log_b_s_r)=(-3.680952380952381, -0.8250000000000002): 17.65
# trying out (10, 21)..
# KSD for (logdt, log_b_s_r)=(-3.6, -0.8250000000000002): 23.12
# trying out (11, 0)..
# KSD for (logdt, log_b_s_r)=(-5.3, -0.6875): 25.71
# trying out (11, 1)..
# KSD for (logdt, log_b_s_r)=(-5.219047619047619, -0.6875): 25.98
# trying out (11, 2)..
# KSD for (logdt, log_b_s_r)=(-5.138095238095238, -0.6875): 24.10
# trying out (11, 3)..
# KSD for (logdt, log_b_s_r)=(-5.057142857142857, -0.6875): 21.98
# trying out (11, 4)..
# KSD for (logdt, log_b_s_r)=(-4.976190476190476, -0.6875): 19.31
# trying out (11, 5)..
# KSD for (logdt, log_b_s_r)=(-4.895238095238095, -0.6875): 18.06
# trying out (11, 6)..
# KSD for (logdt, log_b_s_r)=(-4.814285714285714, -0.6875): 16.45
# trying out (11, 7)..
# KSD for (logdt, log_b_s_r)=(-4.733333333333333, -0.6875): 14.89
# trying out (11, 8)..
# KSD for (logdt, log_b_s_r)=(-4.652380952380952, -0.6875): 14.11
# trying out (11, 9)..
# KSD for (logdt, log_b_s_r)=(-4.571428571428571, -0.6875): 13.17
# trying out (11, 10)..
# KSD for (logdt, log_b_s_r)=(-4.4904761904761905, -0.6875): 11.75
# trying out (11, 11)..
# KSD for (logdt, log_b_s_r)=(-4.40952380952381, -0.6875): 11.14
# trying out (11, 12)..
# KSD for (logdt, log_b_s_r)=(-4.328571428571428, -0.6875): 10.76
# trying out (11, 13)..
# KSD for (logdt, log_b_s_r)=(-4.247619047619048, -0.6875): 10.03
# trying out (11, 14)..
# KSD for (logdt, log_b_s_r)=(-4.166666666666666, -0.6875): 9.55
# trying out (11, 15)..
# KSD for (logdt, log_b_s_r)=(-4.085714285714285, -0.6875): 9.37
# trying out (11, 16)..
# KSD for (logdt, log_b_s_r)=(-4.004761904761905, -0.6875): 9.07
# trying out (11, 17)..
# KSD for (logdt, log_b_s_r)=(-3.923809523809524, -0.6875): 9.44
# trying out (11, 18)..
# KSD for (logdt, log_b_s_r)=(-3.842857142857143, -0.6875): 9.84
# trying out (11, 19)..
# KSD for (logdt, log_b_s_r)=(-3.761904761904762, -0.6875): 10.80
# trying out (11, 20)..
# KSD for (logdt, log_b_s_r)=(-3.680952380952381, -0.6875): 13.09
# trying out (11, 21)..
# KSD for (logdt, log_b_s_r)=(-3.6, -0.6875): 16.23
# trying out (12, 0)..
# KSD for (logdt, log_b_s_r)=(-5.3, -0.55): 27.99
# trying out (12, 1)..
# KSD for (logdt, log_b_s_r)=(-5.219047619047619, -0.55): 30.15
# trying out (12, 2)..
# KSD for (logdt, log_b_s_r)=(-5.138095238095238, -0.55): 27.24
# trying out (12, 3)..
# KSD for (logdt, log_b_s_r)=(-5.057142857142857, -0.55): 25.55
# trying out (12, 4)..
# KSD for (logdt, log_b_s_r)=(-4.976190476190476, -0.55): 21.51
# trying out (12, 5)..
# KSD for (logdt, log_b_s_r)=(-4.895238095238095, -0.55): 18.80
# trying out (12, 6)..
# KSD for (logdt, log_b_s_r)=(-4.814285714285714, -0.55): 16.92
# trying out (12, 7)..
# KSD for (logdt, log_b_s_r)=(-4.733333333333333, -0.55): 15.09
# trying out (12, 8)..
# KSD for (logdt, log_b_s_r)=(-4.652380952380952, -0.55): 13.78
# trying out (12, 9)..
# KSD for (logdt, log_b_s_r)=(-4.571428571428571, -0.55): 13.40
# trying out (12, 10)..
# KSD for (logdt, log_b_s_r)=(-4.4904761904761905, -0.55): 12.15
# trying out (12, 11)..
# KSD for (logdt, log_b_s_r)=(-4.40952380952381, -0.55): 10.27
# trying out (12, 12)..
# KSD for (logdt, log_b_s_r)=(-4.328571428571428, -0.55): 9.60
# trying out (12, 13)..
# KSD for (logdt, log_b_s_r)=(-4.247619047619048, -0.55): 8.74
# trying out (12, 14)..
# KSD for (logdt, log_b_s_r)=(-4.166666666666666, -0.55): 8.69
# trying out (12, 15)..
# KSD for (logdt, log_b_s_r)=(-4.085714285714285, -0.55): 8.18
# trying out (12, 16)..
# KSD for (logdt, log_b_s_r)=(-4.004761904761905, -0.55): 8.36
# trying out (12, 17)..
# KSD for (logdt, log_b_s_r)=(-3.923809523809524, -0.55): 9.23
# trying out (12, 18)..
# KSD for (logdt, log_b_s_r)=(-3.842857142857143, -0.55): 9.30
# trying out (12, 19)..
# KSD for (logdt, log_b_s_r)=(-3.761904761904762, -0.55): 10.29
# trying out (12, 20)..
# KSD for (logdt, log_b_s_r)=(-3.680952380952381, -0.55): 11.73
# trying out (12, 21)..
# KSD for (logdt, log_b_s_r)=(-3.6, -0.55): 14.39
# trying out (13, 0)..
# KSD for (logdt, log_b_s_r)=(-5.3, -0.4125000000000001): 42.12
# trying out (13, 1)..
# KSD for (logdt, log_b_s_r)=(-5.219047619047619, -0.4125000000000001): 40.00
# trying out (13, 2)..
# KSD for (logdt, log_b_s_r)=(-5.138095238095238, -0.4125000000000001): 36.67
# trying out (13, 3)..
# KSD for (logdt, log_b_s_r)=(-5.057142857142857, -0.4125000000000001): 33.53
# trying out (13, 4)..
# KSD for (logdt, log_b_s_r)=(-4.976190476190476, -0.4125000000000001): 30.83
# trying out (13, 5)..
# KSD for (logdt, log_b_s_r)=(-4.895238095238095, -0.4125000000000001): 28.00
# trying out (13, 6)..
# KSD for (logdt, log_b_s_r)=(-4.814285714285714, -0.4125000000000001): 25.76
# trying out (13, 7)..
# KSD for (logdt, log_b_s_r)=(-4.733333333333333, -0.4125000000000001): 23.81
# trying out (13, 8)..
# KSD for (logdt, log_b_s_r)=(-4.652380952380952, -0.4125000000000001): 21.68
# trying out (13, 9)..
# KSD for (logdt, log_b_s_r)=(-4.571428571428571, -0.4125000000000001): 20.10
# trying out (13, 10)..
# KSD for (logdt, log_b_s_r)=(-4.4904761904761905, -0.4125000000000001): 18.57
# trying out (13, 11)..
# KSD for (logdt, log_b_s_r)=(-4.40952380952381, -0.4125000000000001): 17.28
# trying out (13, 12)..
# KSD for (logdt, log_b_s_r)=(-4.328571428571428, -0.4125000000000001): 16.11
# trying out (13, 13)..
# KSD for (logdt, log_b_s_r)=(-4.247619047619048, -0.4125000000000001): 15.13
# trying out (13, 14)..
# KSD for (logdt, log_b_s_r)=(-4.166666666666666, -0.4125000000000001): 14.35
# trying out (13, 15)..
# KSD for (logdt, log_b_s_r)=(-4.085714285714285, -0.4125000000000001): 12.19
# trying out (13, 16)..
# KSD for (logdt, log_b_s_r)=(-4.004761904761905, -0.4125000000000001): 13.68
# trying out (13, 17)..
# KSD for (logdt, log_b_s_r)=(-3.923809523809524, -0.4125000000000001): 13.38
# trying out (13, 18)..
# KSD for (logdt, log_b_s_r)=(-3.842857142857143, -0.4125000000000001): 13.92
# trying out (13, 19)..
# KSD for (logdt, log_b_s_r)=(-3.761904761904762, -0.4125000000000001): 14.40
# trying out (13, 20)..
# KSD for (logdt, log_b_s_r)=(-3.680952380952381, -0.4125000000000001): 15.30
# trying out (13, 21)..
# KSD for (logdt, log_b_s_r)=(-3.6, -0.4125000000000001): 17.41
# trying out (14, 0)..
# KSD for (logdt, log_b_s_r)=(-5.3, -0.2749999999999999): 38.93
# trying out (14, 1)..
# KSD for (logdt, log_b_s_r)=(-5.219047619047619, -0.2749999999999999): 35.32
# trying out (14, 2)..
# KSD for (logdt, log_b_s_r)=(-5.138095238095238, -0.2749999999999999): 32.28
# trying out (14, 3)..
# KSD for (logdt, log_b_s_r)=(-5.057142857142857, -0.2749999999999999): 29.62
# trying out (14, 4)..
# KSD for (logdt, log_b_s_r)=(-4.976190476190476, -0.2749999999999999): 27.02
# trying out (14, 5)..
# KSD for (logdt, log_b_s_r)=(-4.895238095238095, -0.2749999999999999): 24.23
# trying out (14, 6)..
# KSD for (logdt, log_b_s_r)=(-4.814285714285714, -0.2749999999999999): 22.08
# trying out (14, 7)..
# KSD for (logdt, log_b_s_r)=(-4.733333333333333, -0.2749999999999999): 20.80
# trying out (14, 8)..
# KSD for (logdt, log_b_s_r)=(-4.652380952380952, -0.2749999999999999): 18.98
# trying out (14, 9)..
# KSD for (logdt, log_b_s_r)=(-4.571428571428571, -0.2749999999999999): 17.45
# trying out (14, 10)..
# KSD for (logdt, log_b_s_r)=(-4.4904761904761905, -0.2749999999999999): 16.20
# trying out (14, 11)..
# KSD for (logdt, log_b_s_r)=(-4.40952380952381, -0.2749999999999999): 14.42
# trying out (14, 12)..
# KSD for (logdt, log_b_s_r)=(-4.328571428571428, -0.2749999999999999): 14.08
# trying out (14, 13)..
# KSD for (logdt, log_b_s_r)=(-4.247619047619048, -0.2749999999999999): 13.40
# trying out (14, 14)..
# KSD for (logdt, log_b_s_r)=(-4.166666666666666, -0.2749999999999999): 12.91
# trying out (14, 15)..
# KSD for (logdt, log_b_s_r)=(-4.085714285714285, -0.2749999999999999): 12.32
# trying out (14, 16)..
# KSD for (logdt, log_b_s_r)=(-4.004761904761905, -0.2749999999999999): 11.28
# trying out (14, 17)..
# KSD for (logdt, log_b_s_r)=(-3.923809523809524, -0.2749999999999999): 12.13
# trying out (14, 18)..
# KSD for (logdt, log_b_s_r)=(-3.842857142857143, -0.2749999999999999): 12.77
# trying out (14, 19)..
# KSD for (logdt, log_b_s_r)=(-3.761904761904762, -0.2749999999999999): 13.42
# trying out (14, 20)..
# KSD for (logdt, log_b_s_r)=(-3.680952380952381, -0.2749999999999999): 14.51
# trying out (14, 21)..
# KSD for (logdt, log_b_s_r)=(-3.6, -0.2749999999999999): 16.46
# trying out (15, 0)..
# KSD for (logdt, log_b_s_r)=(-5.3, -0.13750000000000018): 38.07
# trying out (15, 1)..
# KSD for (logdt, log_b_s_r)=(-5.219047619047619, -0.13750000000000018): 33.91
# trying out (15, 2)..
# KSD for (logdt, log_b_s_r)=(-5.138095238095238, -0.13750000000000018): 31.92
# trying out (15, 3)..
# KSD for (logdt, log_b_s_r)=(-5.057142857142857, -0.13750000000000018): 28.85
# trying out (15, 4)..
# KSD for (logdt, log_b_s_r)=(-4.976190476190476, -0.13750000000000018): 26.11
# trying out (15, 5)..
# KSD for (logdt, log_b_s_r)=(-4.895238095238095, -0.13750000000000018): 23.13
# trying out (15, 6)..
# KSD for (logdt, log_b_s_r)=(-4.814285714285714, -0.13750000000000018): 21.15
# trying out (15, 7)..
# KSD for (logdt, log_b_s_r)=(-4.733333333333333, -0.13750000000000018): 20.38
# trying out (15, 8)..
# KSD for (logdt, log_b_s_r)=(-4.652380952380952, -0.13750000000000018): 18.19
# trying out (15, 9)..
# KSD for (logdt, log_b_s_r)=(-4.571428571428571, -0.13750000000000018): 15.88
# trying out (15, 10)..
# KSD for (logdt, log_b_s_r)=(-4.4904761904761905, -0.13750000000000018): 15.01
# trying out (15, 11)..
# KSD for (logdt, log_b_s_r)=(-4.40952380952381, -0.13750000000000018): 13.81
# trying out (15, 12)..
# KSD for (logdt, log_b_s_r)=(-4.328571428571428, -0.13750000000000018): 12.92
# trying out (15, 13)..
# KSD for (logdt, log_b_s_r)=(-4.247619047619048, -0.13750000000000018): 12.33
# trying out (15, 14)..
# KSD for (logdt, log_b_s_r)=(-4.166666666666666, -0.13750000000000018): 11.87
# trying out (15, 15)..
# KSD for (logdt, log_b_s_r)=(-4.085714285714285, -0.13750000000000018): 11.59
# trying out (15, 16)..
# KSD for (logdt, log_b_s_r)=(-4.004761904761905, -0.13750000000000018): 11.95
# trying out (15, 17)..
# KSD for (logdt, log_b_s_r)=(-3.923809523809524, -0.13750000000000018): 11.83
# trying out (15, 18)..
# KSD for (logdt, log_b_s_r)=(-3.842857142857143, -0.13750000000000018): 12.62
# trying out (15, 19)..
# KSD for (logdt, log_b_s_r)=(-3.761904761904762, -0.13750000000000018): 13.74
# trying out (15, 20)..
# KSD for (logdt, log_b_s_r)=(-3.680952380952381, -0.13750000000000018): 14.04
# trying out (15, 21)..
# KSD for (logdt, log_b_s_r)=(-3.6, -0.13750000000000018): 13.96
# trying out (16, 0)..
# KSD for (logdt, log_b_s_r)=(-5.3, 0.0): 43.82
# trying out (16, 1)..
# KSD for (logdt, log_b_s_r)=(-5.219047619047619, 0.0): 40.77
# trying out (16, 2)..
# KSD for (logdt, log_b_s_r)=(-5.138095238095238, 0.0): 37.53
# trying out (16, 3)..
# KSD for (logdt, log_b_s_r)=(-5.057142857142857, 0.0): 34.30
# trying out (16, 4)..
# KSD for (logdt, log_b_s_r)=(-4.976190476190476, 0.0): 31.51
# trying out (16, 5)..
# KSD for (logdt, log_b_s_r)=(-4.895238095238095, 0.0): 29.55
# trying out (16, 6)..
# KSD for (logdt, log_b_s_r)=(-4.814285714285714, 0.0): 27.29
# trying out (16, 7)..
# KSD for (logdt, log_b_s_r)=(-4.733333333333333, 0.0): 25.19
# trying out (16, 8)..
# KSD for (logdt, log_b_s_r)=(-4.652380952380952, 0.0): 23.30
# trying out (16, 9)..
# KSD for (logdt, log_b_s_r)=(-4.571428571428571, 0.0): 21.42
# trying out (16, 10)..
# KSD for (logdt, log_b_s_r)=(-4.4904761904761905, 0.0): 19.68
# trying out (16, 11)..
# KSD for (logdt, log_b_s_r)=(-4.40952380952381, 0.0): 18.29
# trying out (16, 12)..
# KSD for (logdt, log_b_s_r)=(-4.328571428571428, 0.0): 16.78
# trying out (16, 13)..
# KSD for (logdt, log_b_s_r)=(-4.247619047619048, 0.0): 15.51
# trying out (16, 14)..
# KSD for (logdt, log_b_s_r)=(-4.166666666666666, 0.0): 14.44
# trying out (16, 15)..
# KSD for (logdt, log_b_s_r)=(-4.085714285714285, 0.0): 13.77
# trying out (16, 16)..
# KSD for (logdt, log_b_s_r)=(-4.004761904761905, 0.0): 13.34
# trying out (16, 17)..
# KSD for (logdt, log_b_s_r)=(-3.923809523809524, 0.0): 12.65
# trying out (16, 18)..
# KSD for (logdt, log_b_s_r)=(-3.842857142857143, 0.0): 12.83
# trying out (16, 19)..
# KSD for (logdt, log_b_s_r)=(-3.761904761904762, 0.0): 14.06
# trying out (16, 20)..
# KSD for (logdt, log_b_s_r)=(-3.680952380952381, 0.0): 14.68
# trying out (16, 21)..
# KSD for (logdt, log_b_s_r)=(-3.6, 0.0): 16.46
# Done.
# Done.

# %% [markdown]
# ### plot `ksd_mat`

# %% [markdown]
# `key=11`:
# - v1: -4.26, 0.20
# - v2: -3.87, 0.22
# - v3: -4.03, 0.19
#
# `key=10`:
# - v4: -4.77, 0.035
# - v5: -5.03, 0.061
# - v6: -4.18, 0.25
#
# `key=9`:
# - v7: -4.51, 0.053
# - v8: -4.80, 0.040
# - v9: -3.96, 0.071

# %%
# ==================
# target: 5 seconds
# opt_sgld_list = [(-4.685606, np.log10(0.03274549)), (-4.124953, np.log10(0.30538556)), 
#                    (-4.1753, np.log10(0.46415886))]
# opt_sgldCV_list = [(-3.9677866, np.log10(0.0053366995)), (-3.7319977, np.log10(0.0015199113)), 
#                    (-3.5236366, np.log10(0.046415884))]

list_params_sgld_5 = [(-4.26, 0.20), (-3.87, 0.22), (-4.03, 0.19),
                     (-4.77, 0.035), (-5.03, 0.061), (-4.18, 0.25),
                      (-4.51, 0.053), (-4.80, 0.040), (-3.96, 0.071)
                     ]
list_params_sgldCV_5 = [(-3.89, 0.0019), (-4.13, 0.019), (-3.74, 0.0087),
                        (-3.92, 0.0057), (-3.91, 0.0087), (-3.92, 0.0035),
                        (-3.81, 0.01), (-3.80, 0.0014), (-3.99, 0.0046)
                       ]

opt_sgld_list = [(elem[0], np.log10(elem[1])) for elem in list_params_sgld_5]
opt_sgldCV_list = [(elem[0], np.log10(elem[1])) for elem in list_params_sgldCV_5]

opt_sgld_default = (-4.8, np.log10(0.1))
opt_sgldCV_default = (-4.2, np.log10(0.1))
# ==================

    
plt.rcParams.update({'font.size': 15})
fig, ax = plt.subplots(1, 2, figsize=(15, 6))

time_budget = 5.0
    
for idx, CV in enumerate([False, True]):
    
    if CV:
        output_dir = "outputs/LR_2d_grid_search/sgld_CV_5sec"
        ksd_mat_LR = np.genfromtxt(f"{output_dir}/LR_2D_gridsearch_high_res_sgld_CV_5sec.txt")
    else:
        output_dir = "outputs/LR_2d_grid_search/sgld_5sec"
        output_dir = "outputs/LR_2d_grid_search/sgld_4.0sec"
        ksd_mat_LR = np.genfromtxt(f"{output_dir}/LR_2d_grid_search4.0sec.txt")
    
        
    CV_string = "_CV" if CV else ""    

    logdt_grid = np.arange(-7,-2.6, 0.2)

    if CV:
        logdt_grid = np.linspace(-5.2,-3, 22)
        log_b_s_r_grid = np.linspace(-4, 0.5, 17)
        # log_b_s_r_grid = np.arange(-5, 0., 0.4)
    else:
        logdt_grid = np.linspace(-5.3,-3.6, 22)
        log_b_s_r_grid = np.linspace(-2.2,0, 17)
        # log_b_s_r_grid = np.arange(-3.5, 0., 0.4)

    XX, YY = np.meshgrid(logdt_grid, log_b_s_r_grid)


    log_ksd_mat = np.log(ksd_mat_LR)


    CS1 = ax[idx].contourf(XX, YY , log_ksd_mat, alpha=0.3)#, levels=[1,20,120])
    CS2 = ax[idx].contour(XX, YY , log_ksd_mat)#, levels=[1,20,120])
    ax[idx].clabel(CS2, inline=True, fontsize=14)
    ax[idx].set_xlabel(r"$\log(h)$", size=17)
    ax[idx].set_ylabel(r"$\log(\tau)$", size=17)
    ax[idx].set_xticks(np.arange(logdt_grid[0],-2.6, 1.))

    if CV:
        for opt_tuple_sgldCV in  opt_sgldCV_list:
            ax[idx].scatter(*opt_tuple_sgldCV, c='b', marker="*", 
                            s=500, label=fr"($log(h)$, $\tau$)={[round(e, 2) for e in opt_tuple_sgldCV]}")
        ax[idx].scatter(*opt_sgldCV_default, c='r', marker="o", s=800)
    else:
        for opt_tuple_sgld in opt_sgld_list:
            ax[idx].scatter(*opt_tuple_sgld, c='b', marker="*", 
                            s=500, label=fr"($log(h)$, $\tau$)={[round(e,2) for e in opt_tuple_sgld]}")
        ax[idx].scatter(*opt_sgld_default, c='r', marker="o", s=800)
    CS1 = fig.colorbar(CS1, ax=ax[idx])
    CS1.ax.set_title("log-KSD", size=15)
#     ax[idx].set_title(f"Logistic regression for sgld{CV_string}\n time budget: {time_budget}sec", size=16)

#     ax[idx].legend(fontsize=13, loc=2)
    
plt.tight_layout()



# plt.savefig(f"images/LR_2D_gridsearch_sgld-sgldCV_5sec.png")

# %%
opt_sgld_list
# Out:
# [(-4.26, -0.6989700043360187),
#  (-3.87, -0.6575773191777937),
#  (-4.03, -0.721246399047171),
#  (-4.77, -1.4559319556497243),
#  (-5.03, -1.214670164989233),
#  (-4.18, -0.6020599913279624),
#  (-4.51, -1.275724130399211),
#  (-4.8, -1.3979400086720375),
#  (-3.96, -1.1487416512809248)]

# %%
print(np.linspace(-5.3,-3.6, 22).shape)
print(np.linspace(-2.2,0, 17).shape)
# Out:
# (22,)
# (17,)

# %%
np.arange(-7,-2.6, 5)
# Out:
# array([-7.])

# %%
np.arange(-3.5, 0., 4).shape
# Out:
# (1,)

# %%
opt_sgldCV_default
# Out:
# (-4.2, -1.0)
